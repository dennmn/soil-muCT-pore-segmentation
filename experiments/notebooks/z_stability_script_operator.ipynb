# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 3. עכשיו תריץ את הפקודה שלך (היא תעבוד כי אנחנו בתיקייה הנכונה)
# !python test_z_patterns.py
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/soil_microCT_images/drive_scripts/z_stability'
# /content/drive/MyDrive/soil_microCT_images/drive_scripts/‏‏z_stability
# configs  outputs	  script_operator.ipynb  STAGE1_SUMMARY.txt
# data	 run_pipeline.py  src			 test_z_patterns.py
#
# ...
# STAGE 2B: Z-PATTERN VALIDATION TESTS
# CPU-only, constructed synthetic volumes
# ...
#
# ...
# TEST 1: Fully Stable Slab
# ...
#
# Expected:
#
#     - Adjacent Dice: 1.0 for all slice pairs
#     - Run-length: Z (10) for all voxels
#     - Persistence: Z (10) for single stable component
#
#
# Actual:
#
#     - Adjacent Dice: min=1.0000, max=1.0000, mean=1.0000
#     - Run-length: mean=10.00, median=10.00
#     - Persistence: mean=10.00, max=10
#
#
# Status: [PASS]
#
# ...
# TEST 2: Single-Slice Appearance
# ...
#
# Expected:
#
#     - Adjacent Dice: 0.0 for pairs around Z=5 (slices 4-5 and 5-6), 1.0 elsewhere (both empty)
#     - Run-length: 1 for voxels at Z=5, 0 elsewhere
# ...

# %%
# %cd /content/drive/MyDrive/soil_microCT_images/drive_scripts/‏‏z_stability
# Out:
# /content/drive/MyDrive/soil_microCT_images/drive_scripts/‏‏z_stability

# %%
# !python run_pipeline.py
# Out:
# Starting Pipeline...
# Processing: /content/drive/MyDrive/soil_microCT_images/ROI/bnei_reem/bnei_reem_ROI_8bit_partial_preproc/masks_pure_otsu
# Loaded 100 slices from /content/drive/MyDrive/soil_microCT_images/ROI/bnei_reem/bnei_reem_ROI_8bit_partial_preproc/masks_pure_otsu/masks -> shape (100, 650, 650)
#
# === MASK VOLUME COUNTS ===
# Value 0 voxels (pore): 9249651
# Value 1 voxels (target): 17711557
# Value 2 voxels (solid): 15288792
# Total voxels: 42250000
# Target class 1: 17711557 (0.4192 fraction)
#
# === Z-METRIC DIAGNOSTICS (target class) ===
# Flip rate: min=0.000000, max=2.000000, mean=0.327361, >0=5293102 (29.89%)
# Frequency (short): min=0.333333, mean=0.890285, median=1.000000, p5=0.666667, p95=1.000000
# Frequency (long):  min=0.142857, mean=0.783539, median=0.857143, p5=0.285714, p95=1.000000
# Unstable frequency (conservative thresholds): short_only=167085 (0.94%), long_only=622716 (3.52%)
#
# Conservative thresholds: freq_short=0.6, flip=2, freq_long=0.3, size=10
# ...

# %%
# !nvidia-smi
# Out:
# Thu Feb  5 09:18:53 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd /content/drive/MyDrive/soil_microCT_images/drive_scripts/
# Out:
# /content/drive/MyDrive/soil_microCT_images/drive_scripts

# %%
# !python preprocess_ct_images.py
  --input_dir '/content/drive/MyDrive/soil_microCT_images/ROI/maoz_scans/mishmar_hanegev_maoz_ROI_16bit_partial/'  --output_dir '/content/drive/MyDrive/soil_microCT_images/ROI/maoz_scans/mishmar_hanegev_maoz_ROI_8bit_partial_preproc/'
# Out:
# Saved: roi_0000_slice0075_clahe61_med5.png
# Saved: roi_0001_slice0076_clahe61_med5.png
# Saved: roi_0002_slice0077_clahe61_med5.png
# Saved: roi_0003_slice0078_clahe61_med5.png
# Saved: roi_0004_slice0079_clahe61_med5.png
# Saved: roi_0005_slice0080_clahe61_med5.png
# Saved: roi_0006_slice0081_clahe61_med5.png
# Saved: roi_0007_slice0082_clahe61_med5.png
# Saved: roi_0008_slice0083_clahe61_med5.png
# Saved: roi_0009_slice0084_clahe61_med5.png
# Saved: roi_0010_slice0085_clahe61_med5.png
# Saved: roi_0011_slice0086_clahe61_med5.png
# Saved: roi_0012_slice0087_clahe61_med5.png
# Saved: roi_0013_slice0088_clahe61_med5.png
# Saved: roi_0014_slice0089_clahe61_med5.png
# Saved: roi_0015_slice0090_clahe61_med5.png
# Saved: roi_0016_slice0091_clahe61_med5.png
# Saved: roi_0017_slice0092_clahe61_med5.png
# Saved: roi_0018_slice0093_clahe61_med5.png
# Saved: roi_0019_slice0094_clahe61_med5.png
# Saved: roi_0020_slice0095_clahe61_med5.png
# Saved: roi_0021_slice0096_clahe61_med5.png
# ...

# %%
# %cd /content/drive/MyDrive/soil_microCT_images/drive_scripts/binary_builder
# Out:
# /content/drive/MyDrive/soil_microCT_images/drive_scripts/binary_builder

# %%
# !python run_binary_builder.py --input_folder '/content/drive/MyDrive/soil_microCT_images/ROI/z_stability_results/rehovot_ROI_8bit_preproc_masks/mask_aggressive/'
# Out:
# ...
# BINARY BUILDER - Semantic Collapse Module
# ...
# Input folder: /content/drive/MyDrive/soil_microCT_images/ROI/z_stability_results/rehovot_ROI_8bit_preproc_masks/mask_aggressive
#
# [1/3] Loading corrected mask stack...
# Loaded 100 slices from /content/drive/MyDrive/soil_microCT_images/ROI/z_stability_results/rehovot_ROI_8bit_preproc_masks/mask_aggressive -> shape (100, 650, 650)
#       Loaded volume shape: (100, 650, 650)
#
# [2/3] Applying semantic collapse rule...
#       Rule: solid != 0, pore = 0
#       Pore voxels:  12,677,905 (30.01%)
#       Solid voxels: 29,572,095 (69.99%)
#
# [3/3] Saving binary outputs...
# Saved 100 slices to /content/drive/MyDrive/soil_microCT_images/ROI/z_stability_results/rehovot_ROI_8bit_preproc_masks/binary_pores
# Saved 100 slices to /content/drive/MyDrive/soil_microCT_images/ROI/z_stability_results/rehovot_ROI_8bit_preproc_masks/binary_solids
#
# ...
# BINARY BUILDER - Complete
# ...
