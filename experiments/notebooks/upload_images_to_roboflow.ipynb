# %% [markdown]
# ### 1. Install Roboflow CLI
# Install the Roboflow CLI which properly handles PNG semantic segmentation masks.
#
# **Note:** The Python SDK does NOT reliably support PNG mask uploads. Use CLI only.

# %%
# Install stable version that handles PNG masks correctly
# Note: Some newer versions (1.1.48+) have UTF-8 decoding bugs with PNG files
# !pip install roboflow==1.1.47 requests
# Out:
# Requirement already satisfied: roboflow==1.1.47 in /usr/local/lib/python3.12/dist-packages (1.1.47)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (2026.1.4)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (11.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (1.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow==1.1.47) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow==1.1.47) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow==1.1.47) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow==1.1.47) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow==1.1.47) (3.3.1)

# %% [markdown]
# ### 2. Authenticate Roboflow CLI
# To interact with Roboflow, you'll need your Roboflow API key. I recommend storing it securely in Colab's Secrets manager. Click the "🔑" icon in the left panel, add a new secret named `ROBOFLOW_API_KEY`, and paste your API key there. Then, run the following cell to set it as an environment variable.

# %%
# Import the Python SDK to access secrets
from google.colab import userdata
import os

# Get the API key from Colab Secrets
ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY_PRIVATE')

# Set the API key as an environment variable for the Roboflow CLI
os.environ["ROBOFLOW_API_KEY"] = ROBOFLOW_API_KEY

print("Roboflow API key loaded and set as environment variable.")
# Out:
# Roboflow API key loaded and set as environment variable.

# %% [markdown]
# ### 3. Mount Google Drive
# To access the folder `G:\My Drive\soil_microCT_images\ROI\png_for_roboflow`, you need to mount your Google Drive in Colab. This will make your Drive files accessible at `/content/drive/My Drive/`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 4. Validate Dataset and Upload via Roboflow CLI
#
# **⚠️ Important: Use Roboflow CLI for Semantic Segmentation PNG Masks**
#
# The Python SDK and REST API do **NOT** reliably support uploading PNG semantic segmentation masks. They cause UTF-8 decoding errors and may corrupt mask values.
#
# **✅ Correct Method: Roboflow CLI**
#
# This script will:
# 1. Validate your dataset (images + masks)
# 2. Verify mask format (PNG uint8 with ignore label 255)
# 3. Upload using the Roboflow CLI command
#
# **Folder Structure Required:**
# ```
# rehovot_ROI_8bit/
#   ├── images/
#   │   ├── image001.png
#   │   └── image002.png
#   └── masks/
#       ├── image001.png  (uint8 grayscale mask)
#       └── image002.png  (uint8 grayscale mask)
# ```

# %%
import os
import glob
import base64
import requests
from pathlib import Path
from roboflow import Roboflow
import numpy as np
from PIL import Image

# ===== CONFIGURATION =====
WORKSPACE_ID = "rony-mr8nv"
PROJECT_ID = "rehovot_seg"

# Base folder containing 'images/' and 'masks/' subfolders
BASE_FOLDER = "/content/drive/My Drive/soil_microCT_images/ROI/weak_supervision_masks/rehovot_ROI_8bit"
IMAGES_FOLDER = os.path.join(BASE_FOLDER, "images")
MASKS_FOLDER = os.path.join(BASE_FOLDER, "masks")

# Optional parameters
BATCH_NAME = "rehovot_semantic_seg"  # Group uploads under this batch name
SPLIT = "train"  # Options: 'train', 'valid', 'test'

# ===== FALLBACK UPLOAD FUNCTION =====
# Used when SDK has UTF-8 decoding bugs with PNG files
def upload_via_rest_api(image_path, mask_path, api_key, project_id, image_name, split="train", batch_name=None):
    """
    Direct REST API upload - binary-safe for PNG masks.
    Preserves uint8 pixel values including ignore label (255).
    """
    # Read image as binary and base64 encode
    with open(image_path, 'rb') as f:
        image_data = base64.b64encode(f.read()).decode('ascii')

    # Read mask as binary and base64 encode
    with open(mask_path, 'rb') as f:
        mask_data = base64.b64encode(f.read()).decode('ascii')

    # Build URL with parameters
    url = f"https://api.roboflow.com/dataset/{project_id}/upload"
    params = {
        "api_key": api_key,
        "name": image_name,
        "split": split
    }
    if batch_name:
        params["batch"] = batch_name

    # Upload image first
    response = requests.post(
        url,
        params=params,
        data=image_data,
        headers={"Content-Type": "application/x-www-form-urlencoded"}
    )

    if response.status_code != 200:
        raise Exception(f"Image upload failed: {response.text}")

    result = response.json()
    image_id = result.get('id')

    if not image_id:
        raise Exception(f"No image ID returned: {result}")

    # Upload mask annotation using the image ID
    mask_url = f"https://api.roboflow.com/dataset/{project_id}/annotate/{image_id}"
    mask_response = requests.post(
        mask_url,
        params={"api_key": api_key, "name": f"{Path(image_name).stem}_mask.png"},
        data=mask_data,
        headers={"Content-Type": "application/x-www-form-urlencoded"}
    )

    if mask_response.status_code != 200:
        raise Exception(f"Mask upload failed: {mask_response.text}")

    return result

# ===== Upload Process =====
# Check folders exist
if not os.path.isdir(IMAGES_FOLDER):
    print(f"❌ Error: Images folder not found: '{IMAGES_FOLDER}'")
elif not os.path.isdir(MASKS_FOLDER):
    print(f"❌ Error: Masks folder not found: '{MASKS_FOLDER}'")
else:
    # Initialize Roboflow
    rf = Roboflow(api_key=ROBOFLOW_API_KEY)
    project = rf.workspace(WORKSPACE_ID).project(PROJECT_ID)

    # Get all image files
    image_extensions = ['*.png', '*.jpg', '*.jpeg', '*.tif', '*.tiff']
    image_files = []
    for ext in image_extensions:
        image_files.extend(glob.glob(os.path.join(IMAGES_FOLDER, ext)))

    print(f"📤 Found {len(image_files)} images to upload")
    print(f"📍 To project: {WORKSPACE_ID}/{PROJECT_ID}")
    print(f"📦 Batch: {BATCH_NAME}")
    print(f"🎯 Project type: Semantic Segmentation (uint8 masks with ignore label 255)\n")

    # Upload each image with its corresponding mask
    uploaded_count = 0
    skipped_count = 0

    for image_path in image_files:
        image_name = Path(image_path).stem
        image_filename = Path(image_path).name

        # Try to find corresponding mask with .png extension
        mask_path = os.path.join(MASKS_FOLDER, f"{image_name}.png")

        if not os.path.exists(mask_path):
            print(f"⚠️  Skipping {image_filename}: No mask found")
            skipped_count += 1
            continue

        # Verify mask is uint8 format
        try:
            mask_img = Image.open(mask_path)
            mask_array = np.array(mask_img)

            if mask_array.dtype != np.uint8:
                print(f"⚠️  Warning: {image_filename} - Mask is not uint8 (found {mask_array.dtype})")

            unique_values = np.unique(mask_array)
            has_ignore = 255 in unique_values
            print(f"🔍 {image_filename}: Mask values {unique_values.min()}-{unique_values.max()}" +
                  (f", includes ignore label (255)" if has_ignore else ""))

        except Exception as e:
            print(f"⚠️  Warning: Could not validate mask for {image_filename}: {e}")

        try:
            # Try SDK upload first (works on roboflow==1.1.47)
            result = project.single_upload(
                image_path=image_path,
                annotation_path=mask_path,
                split=SPLIT,
                batch_name=BATCH_NAME,
                num_retry_uploads=3
            )
            print(f"✅ Uploaded: {image_filename}")
            uploaded_count += 1

        except UnicodeDecodeError as e:
            # Known Roboflow SDK bug: tries to decode binary PNG as UTF-8
            print(f"⚠️  SDK UTF-8 bug detected for {image_filename}")
            print(f"   Falling back to REST API upload (binary-safe)...")

            try:
                # Use REST API fallback - preserves binary PNG data
                upload_via_rest_api(
                    image_path=image_path,
                    mask_path=mask_path,
                    api_key=ROBOFLOW_API_KEY,
                    project_id=PROJECT_ID,
                    image_name=image_filename,
                    split=SPLIT,
                    batch_name=BATCH_NAME
                )
                print(f"✅ Uploaded via REST API: {image_filename}")
                uploaded_count += 1
            except Exception as fallback_error:
                print(f"❌ REST API fallback failed: {str(fallback_error)}")
                skipped_count += 1

        except Exception as e:
            # Check if error message contains UTF-8 codec issue
            error_str = str(e).lower()
            if 'utf-8' in error_str or 'codec' in error_str or 'decode' in error_str:
                print(f"⚠️  UTF-8 encoding issue for {image_filename}")
                print(f"   This is a known Roboflow SDK bug with binary PNG files.")
                print(f"   Falling back to REST API upload...")

                try:
                    upload_via_rest_api(
                        image_path=image_path,
                        mask_path=mask_path,
                        api_key=ROBOFLOW_API_KEY,
                        project_id=PROJECT_ID,
                        image_name=image_filename,
                        split=SPLIT,
                        batch_name=BATCH_NAME
                    )
                    print(f"✅ Uploaded via REST API: {image_filename}")
                    uploaded_count += 1
                except Exception as fallback_error:
                    print(f"❌ REST API fallback failed: {str(fallback_error)}")
                    skipped_count += 1
            else:
                print(f"❌ Error uploading {image_filename}: {str(e)}")
                skipped_count += 1

    print(f"\n🎉 Upload complete!")
    print(f"   Uploaded: {uploaded_count}")
    print(f"   Skipped: {skipped_count}")
    print(f"\n💡 Note: Verify in Roboflow UI that masks display correctly and class 255 is preserved.")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# 📤 Found 661 images to upload
# 📍 To project: rony-mr8nv/rehovot_seg
# 📦 Batch: rehovot_semantic_seg
# 🎯 Project type: Semantic Segmentation (uint8 masks with ignore label 255)
#
# 🔍 roi_0000_slice0120_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0000_slice0120_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0001_slice0121_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0001_slice0121_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0002_slice0122_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0002_slice0122_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0003_slice0123_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0003_slice0123_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0004_slice0124_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0004_slice0124_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0005_slice0125_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0005_slice0125_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0006_slice0126_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0006_slice0126_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0007_slice0127_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0007_slice0127_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0008_slice0128_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0008_slice0128_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0009_slice0129_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0009_slice0129_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0010_slice0130_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0010_slice0130_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0011_slice0131_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0011_slice0131_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0012_slice0132_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0012_slice0132_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0013_slice0133_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0013_slice0133_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0014_slice0134_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0014_slice0134_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0015_slice0135_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0015_slice0135_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0016_slice0136_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0016_slice0136_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0017_slice0137_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0017_slice0137_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0018_slice0138_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0018_slice0138_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0019_slice0139_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0019_slice0139_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0020_slice0140_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0020_slice0140_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0021_slice0141_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0021_slice0141_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0022_slice0142_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0022_slice0142_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0023_slice0143_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0023_slice0143_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0024_slice0144_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0024_slice0144_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0025_slice0145_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0025_slice0145_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0026_slice0146_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0026_slice0146_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0027_slice0147_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0027_slice0147_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0028_slice0148_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0028_slice0148_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0029_slice0149_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0029_slice0149_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0030_slice0150_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0030_slice0150_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0031_slice0151_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0031_slice0151_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0032_slice0152_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0032_slice0152_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0033_slice0153_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0033_slice0153_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0034_slice0154_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0034_slice0154_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0035_slice0155_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0035_slice0155_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0036_slice0156_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0036_slice0156_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0037_slice0157_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0037_slice0157_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0038_slice0158_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0038_slice0158_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0039_slice0159_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0039_slice0159_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0040_slice0160_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0040_slice0160_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0041_slice0161_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0041_slice0161_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0042_slice0162_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0042_slice0162_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0043_slice0163_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0043_slice0163_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0044_slice0164_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0044_slice0164_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0045_slice0165_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0045_slice0165_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0046_slice0166_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0046_slice0166_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0047_slice0167_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0047_slice0167_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0048_slice0168_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0048_slice0168_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0049_slice0169_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0049_slice0169_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0050_slice0170_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0050_slice0170_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0051_slice0171_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0051_slice0171_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0052_slice0172_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0052_slice0172_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0053_slice0173_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0053_slice0173_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0054_slice0174_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0054_slice0174_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0055_slice0175_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0055_slice0175_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0056_slice0176_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0056_slice0176_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0057_slice0177_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0057_slice0177_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0058_slice0178_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0058_slice0178_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0059_slice0179_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0059_slice0179_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0060_slice0180_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0060_slice0180_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0061_slice0181_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0061_slice0181_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0062_slice0182_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0062_slice0182_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0063_slice0183_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0063_slice0183_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0064_slice0184_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0064_slice0184_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0065_slice0185_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0065_slice0185_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0066_slice0186_norm8.png: Mask values 0-255, includes ignore label (255)
# ...
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0181_slice0301_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0181_slice0301_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0182_slice0302_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0182_slice0302_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0183_slice0303_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0183_slice0303_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0184_slice0304_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0184_slice0304_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0185_slice0305_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0185_slice0305_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0186_slice0306_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0186_slice0306_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0187_slice0307_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0187_slice0307_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0188_slice0308_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0188_slice0308_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0189_slice0309_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0189_slice0309_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0190_slice0310_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0190_slice0310_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0191_slice0311_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0191_slice0311_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0192_slice0312_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0192_slice0312_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0193_slice0313_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0193_slice0313_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0194_slice0314_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0194_slice0314_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0195_slice0315_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0195_slice0315_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0196_slice0316_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0196_slice0316_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0197_slice0317_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0197_slice0317_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0198_slice0318_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0198_slice0318_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0199_slice0319_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0199_slice0319_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0200_slice0320_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0200_slice0320_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# 🔍 roi_0201_slice0321_norm8.png: Mask values 0-255, includes ignore label (255)
# ⚠️  SDK UTF-8 bug detected for roi_0201_slice0321_norm8.png
#    Falling back to REST API upload (binary-safe)...
# ❌ REST API fallback failed: Mask upload failed: {
#     "error": {
#         "message": "Unrecognized annotation format.",
#         "type": "InvalidAnnotationFormat",
#         "hint": "We were unable to parse your annotation format or it is not supported via the upload API at this time. Ensure that the annotations file provided in the request contains annotations for the provided image.",
#         "annotation": {
#             "info": {
#                 "type": "unknown",
#                 "format": "png"
#             }
#         }
#     }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2556722046.py in <cell line: 0>()
#     117         # Verify mask is uint8 format
#     118         try:
# --> 119             mask_img = Image.open(mask_path)
#     120             mask_array = np.array(mask_img)
#     121
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3522         exclusive_fp = True
#    3523
# -> 3524     prefix = fp.read(16)
#    3525
#    3526     preinit()
#
# KeyboardInterrupt:
