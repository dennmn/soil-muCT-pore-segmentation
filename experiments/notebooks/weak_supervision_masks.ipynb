# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # WEAK-SUPERVISION MASK GENERATION
#
# ## Purpose
# Generates weak-supervision segmentation masks by combining original µCT slices with Multi-Otsu segmentation outputs. The script computes confidence heuristics from the original images to identify and mark uncertain regions as ignored, suitable for nnU-Net training with excluded regions.
#
# ## Inputs
# - Directory containing original µCT slice images (TIFF or PNG)
# - Directory containing corresponding Multi-Otsu segmentation slices
# - Files are matched by filename (sorted alphabetically)
#
# ## Outputs
# - Directory containing weak-supervision mask slices
# - Single-channel images (same spatial dimensions as input)
# - Pixel values encode:
#   * 0, 1, 2, ... : valid pseudo-labels from Multi-Otsu
#   * IGNORE_LABEL : uncertain/ignored regions (default: 255)
#
# ## Behavior
# For each slice pair:
# 1. Load original image and its Multi-Otsu segmentation
# 2. Use Multi-Otsu labels as initial class assignment
# 3. Compute confidence heuristics from original image:
#    - Local intensity variance (heterogeneity)
#    - Gradient magnitude (edge strength)
#    - Boundary proximity (distance to class boundaries)
# 4. Mark voxels as ignored if confidence criteria are violated
# 5. Preserve confident regions unchanged
#
# All operations are deterministic (no randomness, no learning).
#
# ## Assumptions
# - Files in both directories are paired by filename and sorted order
# - Multi-Otsu segmentation has class values 0, 1, 2, ...
# - Original images are grayscale uint8 or uint16
# - No missing files or mismatched dimensions
#
# ## Dependencies
# numpy, scipy, scikit-image, tifffile (or imageio)

# %%
import os
from pathlib import Path
import numpy as np
from scipy import ndimage
from skimage import filters, morphology
from skimage.util import img_as_ubyte, img_as_float32
import tifffile
from tifffile import TiffFile

# %% [markdown]
# ## CONFIGURATION

# %%
# Input directories
INPUT_ORIGINAL_DIR = "/content/drive/MyDrive/soil_microCT_images/ROI/rehovot_ROI_8bit"
INPUT_MULTIOTSU_DIR = "/content/drive/MyDrive/soil_microCT_images/ROI/multiotsu_pores_outputs/rehovot_ROI_8bit/pores_class0_plus_1"

# Output directory
OUTPUT_DIR = "/content/drive/MyDrive/soil_microCT_images/ROI/weak_supervision_masks/rehovot_ROI_8bit"

# Label for ignored/uncertain regions
IGNORE_LABEL = 255

# Class label for pores/air (typically 0 = darkest class in Multi-Otsu)
# All other labels are considered solid material
PORE_LABEL = 0

# Confidence thresholds as percentiles (0-100)
# Higher percentiles = stricter filtering = more regions ignored
# These are applied to per-slice statistics (adaptive)
VARIANCE_PERCENTILE = 90.0       # Percentile for local variance (90 = top 10% marked uncertain)
GRADIENT_PERCENTILE = 90.0       # Percentile for gradient magnitude (90 = top 10% marked uncertain)
BOUNDARY_DISTANCE_THRESHOLD = 3  # Pixels from pore↔solid boundaries to ignore

# Window size for local statistics (pixels)
LOCAL_WINDOW_SIZE = 7

# File extensions to process
EXTS = {".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp"}

# %% [markdown]
# ## HELPER FUNCTIONS

# %%
def ensure_dir(p):
    """Create directory if it doesn't exist."""
    Path(p).mkdir(parents=True, exist_ok=True)


def list_images(folder):
    """List all image files in a folder, sorted alphabetically."""
    folder = Path(folder)
    files = []
    if not folder.exists():
        print(f"Warning: folder does not exist: {folder}")
        return files
    for f in folder.iterdir():
        if f.is_file() and f.suffix.lower() in EXTS:
            files.append(str(f))
    return sorted(files)


def extract_slice_identifier(filename):
    """
    Extracts the common slice identifier from a filename.
    Assumes identifier is everything before '_pores_' or the base filename.
    """
    name_without_ext = Path(filename).stem
    # Example: 'roi_0660_slice0780_norm8_pores_class0plus1' -> 'roi_0660_slice0780_norm8'
    # Example: 'roi_0660_slice0780_norm8' -> 'roi_0660_slice0780_norm8'
    if "_pores_" in name_without_ext:
        return name_without_ext.split("_pores_")[0]
    return name_without_ext


def load_image(path):
    """Load image as grayscale numpy array."""
    try:
        # Try tifffile first (handles 16-bit TIFF well)
        img = tifffile.imread(path)
        if img.ndim == 3:
            # Convert RGB to grayscale if needed
            img = np.mean(img, axis=-1).astype(img.dtype)
        return img
    except Exception:
        # Fallback: try PIL or other loaders
        from PIL import Image
        img = Image.open(path)
        if img.mode != 'L':
            img = img.convert('L')
        return np.array(img)

# %%
def compute_local_variance(image, window_size):
    """
    Compute local intensity variance using uniform filter.

    High variance indicates heterogeneous/uncertain regions.
    """
    image_f = img_as_float32(image)

    # Local mean
    local_mean = ndimage.uniform_filter(image_f, size=window_size)

    # Local mean of squared values
    local_mean_sq = ndimage.uniform_filter(image_f ** 2, size=window_size)

    # Variance = E[X^2] - E[X]^2
    local_var = local_mean_sq - local_mean ** 2
    local_var = np.maximum(local_var, 0)  # Avoid numerical negatives

    return local_var


def compute_gradient_magnitude(image):
    """
    Compute gradient magnitude using Sobel operator.

    High gradient indicates strong edges, which may be uncertain boundaries.
    """
    image_f = img_as_float32(image)

    # Sobel filters
    grad_x = ndimage.sobel(image_f, axis=1)
    grad_y = ndimage.sobel(image_f, axis=0)

    # Magnitude
    grad_mag = np.sqrt(grad_x**2 + grad_y**2)

    return grad_mag


def compute_boundary_mask(segmentation, pore_label, distance_threshold):
    """
    Identify pixels near pore↔solid boundaries.

    Only pore/air to solid transitions are physically ambiguous in µCT.
    Solid↔solid boundaries remain confident.
    """
    # Create binary pore mask
    pore_mask = (segmentation == pore_label)

    # Find pore boundaries: dilate pores and find overlap with solids
    dilated_pores = morphology.binary_dilation(pore_mask)
    pore_boundary = dilated_pores & ~pore_mask  # Solid pixels adjacent to pores

    # Also mark pore pixels adjacent to solids
    eroded_pores = morphology.binary_erosion(pore_mask)
    pore_edge = pore_mask & ~eroded_pores  # Pore pixels at boundary

    # Combine: uncertainty zone includes both sides of pore↔solid interface
    boundary = pore_boundary | pore_edge

    # Dilate boundary to create uncertainty zone
    if distance_threshold > 0:
        selem = morphology.disk(distance_threshold)
        boundary = morphology.binary_dilation(boundary, selem)

    return boundary

# %%
def generate_weak_supervision_mask(original, multiotsu_seg, config):
    """
    Generate weak-supervision mask by marking uncertain regions.

    Parameters:
    -----------
    original : ndarray
        Original grayscale image
    multiotsu_seg : ndarray
        Multi-Otsu segmentation (class labels: 0, 1, 2, ...)
    config : dict
        Configuration dictionary with thresholds

    Returns:
    --------
    mask : ndarray (uint8)
        Weak-supervision mask with confident labels and ignored regions
    """
    h, w = original.shape

    # Initialize mask with Multi-Otsu labels
    mask = multiotsu_seg.astype(np.uint8).copy()

    # Compute confidence heuristics
    print("  Computing local variance...", end=" ")
    local_var = compute_local_variance(original, config['local_window_size'])
    print("done")

    print("  Computing gradient magnitude...", end=" ")
    grad_mag = compute_gradient_magnitude(original)
    print("done")

    print("  Computing pore↔solid boundary mask...", end=" ")
    boundary = compute_boundary_mask(multiotsu_seg, config['pore_label'], config['boundary_distance_threshold'])
    print("done")

    # Compute adaptive thresholds from per-slice statistics (percentile-based)
    # This accounts for slice-to-slice variation and float32 normalization
    var_thresh = np.percentile(local_var, config['variance_percentile']) if config['variance_percentile'] > 0 else np.inf
    grad_thresh = np.percentile(grad_mag, config['gradient_percentile']) if config['gradient_percentile'] > 0 else np.inf

    print(f"  Adaptive variance threshold: {var_thresh:.6f}")
    print(f"  Adaptive gradient threshold: {grad_thresh:.6f}")

    # Identify uncertain regions (logical OR of all criteria)
    uncertain = np.zeros((h, w), dtype=bool)

    # High variance regions (heterogeneous texture)
    if config['variance_percentile'] > 0:
        high_var = local_var > var_thresh
        uncertain |= high_var
        print(f"  High variance pixels: {high_var.sum()} ({100*high_var.mean():.2f}%)")

    # High gradient regions (strong edges)
    if config['gradient_percentile'] > 0:
        high_grad = grad_mag > grad_thresh
        uncertain |= high_grad
        print(f"  High gradient pixels: {high_grad.sum()} ({100*high_grad.mean():.2f}%)")

    # Near pore↔solid boundaries (physically ambiguous interfaces)
    if config['boundary_distance_threshold'] > 0:
        uncertain |= boundary
        print(f"  Pore↔solid boundary pixels: {boundary.sum()} ({100*boundary.mean():.2f}%)")

    # Mark uncertain regions with ignore label
    mask[uncertain] = config['ignore_label']

    total_ignored = uncertain.sum()
    print(f"  Total ignored pixels: {total_ignored} ({100*total_ignored/(h*w):.2f}%)")

    return mask

# %% [markdown]
# ## MAIN PROCESSING

# %%
print("=" * 60)
print("WEAK-SUPERVISION MASK GENERATION")
print("=" * 60)
print()

# Configuration dictionary
config = {
    'ignore_label': IGNORE_LABEL,
    'pore_label': PORE_LABEL,
    'variance_percentile': VARIANCE_PERCENTILE,
    'gradient_percentile': GRADIENT_PERCENTILE,
    'boundary_distance_threshold': BOUNDARY_DISTANCE_THRESHOLD,
    'local_window_size': LOCAL_WINDOW_SIZE,
}

print("Configuration:")
print(f"  Input original dir: {INPUT_ORIGINAL_DIR}")
print(f"  Input Multi-Otsu dir: {INPUT_MULTIOTSU_DIR}")
print(f"  Output dir: {OUTPUT_DIR}")
print(f"  Ignore label: {IGNORE_LABEL}")
print(f"  Pore label: {PORE_LABEL}")
print(f"  Variance percentile: {VARIANCE_PERCENTILE}")
print(f"  Gradient percentile: {GRADIENT_PERCENTILE}")
print(f"  Boundary distance: {BOUNDARY_DISTANCE_THRESHOLD} px (pore↔solid only)")
print(f"  Local window size: {LOCAL_WINDOW_SIZE} px")
print()
# Out:
# ============================================================
# WEAK-SUPERVISION MASK GENERATION
# ============================================================
#
# Configuration:
#   Input original dir: /content/drive/MyDrive/soil_microCT_images/ROI/rehovot_ROI_8bit
#   Input Multi-Otsu dir: /content/drive/MyDrive/soil_microCT_images/ROI/multiotsu_pores_outputs/rehovot_ROI_8bit/pores_class0_plus_1
#   Output dir: /content/drive/MyDrive/soil_microCT_images/ROI/weak_supervision_masks/rehovot_ROI_8bit
#   Ignore label: 255
#   Pore label: 0
#   Variance percentile: 90.0
#   Gradient percentile: 90.0
#   Boundary distance: 3 px (pore↔solid only)
#   Local window size: 7 px

# %%
# Create output directory
ensure_dir(OUTPUT_DIR)

# List raw image file paths from both directories
original_files_list = list_images(INPUT_ORIGINAL_DIR)
multiotsu_files_list = list_images(INPUT_MULTIOTSU_DIR)

print(f"Found {len(original_files_list)} original images (raw count)")
print(f"Found {len(multiotsu_files_list)} Multi-Otsu segmentations (raw count)")
print()

# Create maps for identifiers to full paths
original_map = {extract_slice_identifier(Path(f).name): f for f in original_files_list}
multiotsu_map = {extract_slice_identifier(Path(f).name): f for f in multiotsu_files_list}

print(f"Found {len(original_map)} unique original image identifiers")
print(f"Found {len(multiotsu_map)} unique Multi-Otsu segmentation identifiers")
print()

# Find common identifiers to process
common_identifiers = sorted(list(set(original_map.keys()) & set(multiotsu_map.keys())))

if not common_identifiers:
    print("Error: No common image identifiers found between directories. Exiting.")
    # Set n_pairs to 0 to prevent further processing in the next cell
    n_pairs = 0
else:
    n_pairs = len(common_identifiers)
    print(f"Will process {n_pairs} image pairs based on common identifiers.\n")

    # Print warnings for unmatched files
    for identifier in original_map.keys():
        if identifier not in common_identifiers:
            print(f"Warning: Original image '{Path(original_map[identifier]).name}' (identifier: '{identifier}') has no matching Multi-Otsu segmentation. Skipping.")
    for identifier in multiotsu_map.keys():
        if identifier not in common_identifiers:
            print(f"Warning: Multi-Otsu segmentation '{Path(multiotsu_map[identifier]).name}' (identifier: '{identifier}') has no matching original image. Skipping.")
    print()
# Out:
# Found 661 original images (raw count)
# Found 661 Multi-Otsu segmentations (raw count)
#
# Found 661 unique original image identifiers
# Found 661 unique Multi-Otsu segmentation identifiers
#
# Will process 661 image pairs based on common identifiers.

# %%
# Process image pairs
# n_pairs is already determined in the previous cell. If n_pairs is 0, the loop will not execute.

for i, identifier in enumerate(common_identifiers):
    orig_path = original_map[identifier]
    seg_path = multiotsu_map[identifier]

    orig_name = Path(orig_path).name
    seg_name = Path(seg_path).name

    print(f"[{i+1}/{n_pairs}] Processing identifier: {identifier}")
    print(f"  Original: {orig_name}")
    print(f"  Multi-Otsu: {seg_name}")

    # Load images
    try:
        original = load_image(orig_path)
        multiotsu_seg = load_image(seg_path)
    except Exception as e:
        print(f"  Error loading images: {e}")
        print(f"  Skipping pair for identifier '{identifier}'")
        print()
        continue

    # Check dimensions match
    if original.shape != multiotsu_seg.shape:
        print(f"  Error: Shape mismatch for identifier '{identifier}' ({original.shape} vs {multiotsu_seg.shape})")
        print(f"  Skipping pair for identifier '{identifier}'")
        print()
        continue

    # Generate weak-supervision mask
    try:
        ws_mask = generate_weak_supervision_mask(original, multiotsu_seg, config)
    except Exception as e:
        print(f"  Error generating mask for identifier '{identifier}': {e}")
        print(f"  Skipping pair for identifier '{identifier}'")
        print()
        continue

    # Save output
    # Use the identifier as the base filename for consistency
    out_name = identifier + ".png"
    out_path = os.path.join(OUTPUT_DIR, out_name)

    try:
        tifffile.imwrite(out_path, ws_mask, compression='deflate')
        print(f"  Saved: {out_name}")
    except Exception as e:
        print(f"  Error saving mask for identifier '{identifier}': {e}")

    print()

print("=" * 60)
print(f"COMPLETED: Processed {n_pairs} image pairs")
print(f"Output directory: {OUTPUT_DIR}")
print("=" * 60)
# Out:
# Streaming output truncated to the last 5000 lines.
#   Multi-Otsu: roi_0304_slice0424_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065658
#   Adaptive gradient threshold: 1.560863
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 304621 (72.10%)
#   Total ignored pixels: 312633 (74.00%)
#   Saved: roi_0304_slice0424_norm8.png
#
# [306/661] Processing identifier: roi_0305_slice0425_norm8
#   Original: roi_0305_slice0425_norm8.tif
#   Multi-Otsu: roi_0305_slice0425_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065155
#   Adaptive gradient threshold: 1.558418
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 303883 (71.92%)
#   Total ignored pixels: 312697 (74.01%)
#   Saved: roi_0305_slice0425_norm8.png
#
# [307/661] Processing identifier: roi_0306_slice0426_norm8
#   Original: roi_0306_slice0426_norm8.tif
#   Multi-Otsu: roi_0306_slice0426_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.063544
#   Adaptive gradient threshold: 1.537935
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 304585 (72.09%)
#   Total ignored pixels: 313342 (74.16%)
#   Saved: roi_0306_slice0426_norm8.png
#
# [308/661] Processing identifier: roi_0307_slice0427_norm8
#   Original: roi_0307_slice0427_norm8.tif
#   Multi-Otsu: roi_0307_slice0427_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064996
#   Adaptive gradient threshold: 1.557974
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 306957 (72.65%)
#   Total ignored pixels: 315253 (74.62%)
#   Saved: roi_0307_slice0427_norm8.png
#
# [309/661] Processing identifier: roi_0308_slice0428_norm8
#   Original: roi_0308_slice0428_norm8.tif
#   Multi-Otsu: roi_0308_slice0428_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067289
#   Adaptive gradient threshold: 1.582886
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 305921 (72.41%)
#   Total ignored pixels: 314372 (74.41%)
#   Saved: roi_0308_slice0428_norm8.png
#
# [310/661] Processing identifier: roi_0309_slice0429_norm8
#   Original: roi_0309_slice0429_norm8.tif
#   Multi-Otsu: roi_0309_slice0429_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062110
#   Adaptive gradient threshold: 1.521831
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 308357 (72.98%)
#   Total ignored pixels: 316384 (74.88%)
#   Saved: roi_0309_slice0429_norm8.png
#
# [311/661] Processing identifier: roi_0310_slice0430_norm8
#   Original: roi_0310_slice0430_norm8.tif
#   Multi-Otsu: roi_0310_slice0430_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062392
#   Adaptive gradient threshold: 1.521862
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 304065 (71.97%)
#   Total ignored pixels: 313070 (74.10%)
#   Saved: roi_0310_slice0430_norm8.png
#
# [312/661] Processing identifier: roi_0311_slice0431_norm8
#   Original: roi_0311_slice0431_norm8.tif
#   Multi-Otsu: roi_0311_slice0431_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067119
#   Adaptive gradient threshold: 1.574987
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 308319 (72.97%)
#   Total ignored pixels: 315300 (74.63%)
#   Saved: roi_0311_slice0431_norm8.png
#
# [313/661] Processing identifier: roi_0312_slice0432_norm8
#   Original: roi_0312_slice0432_norm8.tif
#   Multi-Otsu: roi_0312_slice0432_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068102
#   Adaptive gradient threshold: 1.585886
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42244 (10.00%)
#   Pore↔solid boundary pixels: 307460 (72.77%)
#   Total ignored pixels: 314619 (74.47%)
#   Saved: roi_0312_slice0432_norm8.png
#
# [314/661] Processing identifier: roi_0313_slice0433_norm8
#   Original: roi_0313_slice0433_norm8.tif
#   Multi-Otsu: roi_0313_slice0433_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065963
#   Adaptive gradient threshold: 1.564272
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 307729 (72.84%)
#   Total ignored pixels: 315315 (74.63%)
#   Saved: roi_0313_slice0433_norm8.png
#
# [315/661] Processing identifier: roi_0314_slice0434_norm8
#   Original: roi_0314_slice0434_norm8.tif
#   Multi-Otsu: roi_0314_slice0434_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.072732
#   Adaptive gradient threshold: 1.646062
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310293 (73.44%)
#   Total ignored pixels: 317656 (75.18%)
#   Saved: roi_0314_slice0434_norm8.png
#
# [316/661] Processing identifier: roi_0315_slice0435_norm8
#   Original: roi_0315_slice0435_norm8.tif
#   Multi-Otsu: roi_0315_slice0435_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068771
#   Adaptive gradient threshold: 1.601480
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 311762 (73.79%)
#   Total ignored pixels: 318584 (75.40%)
#   Saved: roi_0315_slice0435_norm8.png
#
# [317/661] Processing identifier: roi_0316_slice0436_norm8
#   Original: roi_0316_slice0436_norm8.tif
#   Multi-Otsu: roi_0316_slice0436_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067499
#   Adaptive gradient threshold: 1.581944
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310084 (73.39%)
#   Total ignored pixels: 317520 (75.15%)
#   Saved: roi_0316_slice0436_norm8.png
#
# [318/661] Processing identifier: roi_0317_slice0437_norm8
#   Original: roi_0317_slice0437_norm8.tif
#   Multi-Otsu: roi_0317_slice0437_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069911
#   Adaptive gradient threshold: 1.613333
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 309271 (73.20%)
#   Total ignored pixels: 317068 (75.05%)
#   Saved: roi_0317_slice0437_norm8.png
#
# [319/661] Processing identifier: roi_0318_slice0438_norm8
#   Original: roi_0318_slice0438_norm8.tif
#   Multi-Otsu: roi_0318_slice0438_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070415
#   Adaptive gradient threshold: 1.619337
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 306136 (72.46%)
#   Total ignored pixels: 315019 (74.56%)
#   Saved: roi_0318_slice0438_norm8.png
#
# [320/661] Processing identifier: roi_0319_slice0439_norm8
#   Original: roi_0319_slice0439_norm8.tif
#   Multi-Otsu: roi_0319_slice0439_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067101
#   Adaptive gradient threshold: 1.582877
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 305810 (72.38%)
#   Total ignored pixels: 313984 (74.32%)
#   Saved: roi_0319_slice0439_norm8.png
#
# [321/661] Processing identifier: roi_0320_slice0440_norm8
#   Original: roi_0320_slice0440_norm8.tif
#   Multi-Otsu: roi_0320_slice0440_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.071876
#   Adaptive gradient threshold: 1.635073
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 306215 (72.48%)
#   Total ignored pixels: 315373 (74.64%)
#   Saved: roi_0320_slice0440_norm8.png
#
# [322/661] Processing identifier: roi_0321_slice0441_norm8
#   Original: roi_0321_slice0441_norm8.tif
#   Multi-Otsu: roi_0321_slice0441_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.071642
#   Adaptive gradient threshold: 1.634622
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 306878 (72.63%)
#   Total ignored pixels: 314829 (74.52%)
#   Saved: roi_0321_slice0441_norm8.png
#
# [323/661] Processing identifier: roi_0322_slice0442_norm8
#   Original: roi_0322_slice0442_norm8.tif
#   Multi-Otsu: roi_0322_slice0442_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.075271
#   Adaptive gradient threshold: 1.672943
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 308676 (73.06%)
#   Total ignored pixels: 316743 (74.97%)
#   Saved: roi_0322_slice0442_norm8.png
#
# [324/661] Processing identifier: roi_0323_slice0443_norm8
#   Original: roi_0323_slice0443_norm8.tif
#   Multi-Otsu: roi_0323_slice0443_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070226
#   Adaptive gradient threshold: 1.619651
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 310410 (73.47%)
#   Total ignored pixels: 318464 (75.38%)
#   Saved: roi_0323_slice0443_norm8.png
#
# [325/661] Processing identifier: roi_0324_slice0444_norm8
#   Original: roi_0324_slice0444_norm8.tif
#   Multi-Otsu: roi_0324_slice0444_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064768
#   Adaptive gradient threshold: 1.559118
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 307833 (72.86%)
#   Total ignored pixels: 316412 (74.89%)
#   Saved: roi_0324_slice0444_norm8.png
#
# [326/661] Processing identifier: roi_0325_slice0445_norm8
#   Original: roi_0325_slice0445_norm8.tif
#   Multi-Otsu: roi_0325_slice0445_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065850
#   Adaptive gradient threshold: 1.567156
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 307378 (72.75%)
#   Total ignored pixels: 315966 (74.78%)
#   Saved: roi_0325_slice0445_norm8.png
#
# [327/661] Processing identifier: roi_0326_slice0446_norm8
#   Original: roi_0326_slice0446_norm8.tif
#   Multi-Otsu: roi_0326_slice0446_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067520
#   Adaptive gradient threshold: 1.586225
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 307009 (72.66%)
#   Total ignored pixels: 315305 (74.63%)
#   Saved: roi_0326_slice0446_norm8.png
#
# [328/661] Processing identifier: roi_0327_slice0447_norm8
#   Original: roi_0327_slice0447_norm8.tif
#   Multi-Otsu: roi_0327_slice0447_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069857
#   Adaptive gradient threshold: 1.615204
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310821 (73.57%)
#   Total ignored pixels: 318433 (75.37%)
#   Saved: roi_0327_slice0447_norm8.png
#
# [329/661] Processing identifier: roi_0328_slice0448_norm8
#   Original: roi_0328_slice0448_norm8.tif
#   Multi-Otsu: roi_0328_slice0448_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067501
#   Adaptive gradient threshold: 1.592302
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 305792 (72.38%)
#   Total ignored pixels: 314854 (74.52%)
#   Saved: roi_0328_slice0448_norm8.png
#
# [330/661] Processing identifier: roi_0329_slice0449_norm8
#   Original: roi_0329_slice0449_norm8.tif
#   Multi-Otsu: roi_0329_slice0449_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070949
#   Adaptive gradient threshold: 1.639244
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 308921 (73.12%)
#   Total ignored pixels: 317067 (75.05%)
#   Saved: roi_0329_slice0449_norm8.png
#
# [331/661] Processing identifier: roi_0330_slice0450_norm8
#   Original: roi_0330_slice0450_norm8.tif
#   Multi-Otsu: roi_0330_slice0450_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070558
#   Adaptive gradient threshold: 1.636653
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42245 (10.00%)
#   Pore↔solid boundary pixels: 309580 (73.27%)
#   Total ignored pixels: 317429 (75.13%)
#   Saved: roi_0330_slice0450_norm8.png
#
# [332/661] Processing identifier: roi_0331_slice0451_norm8
#   Original: roi_0331_slice0451_norm8.tif
#   Multi-Otsu: roi_0331_slice0451_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.066732
#   Adaptive gradient threshold: 1.583314
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42245 (10.00%)
#   Pore↔solid boundary pixels: 304638 (72.10%)
#   Total ignored pixels: 313799 (74.27%)
#   Saved: roi_0331_slice0451_norm8.png
#
# [333/661] Processing identifier: roi_0332_slice0452_norm8
#   Original: roi_0332_slice0452_norm8.tif
#   Multi-Otsu: roi_0332_slice0452_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.076984
#   Adaptive gradient threshold: 1.696730
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 306641 (72.58%)
#   Total ignored pixels: 315201 (74.60%)
#   Saved: roi_0332_slice0452_norm8.png
#
# [334/661] Processing identifier: roi_0333_slice0453_norm8
#   Original: roi_0333_slice0453_norm8.tif
#   Multi-Otsu: roi_0333_slice0453_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069646
#   Adaptive gradient threshold: 1.617018
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 305202 (72.24%)
#   Total ignored pixels: 314620 (74.47%)
#   Saved: roi_0333_slice0453_norm8.png
#
# [335/661] Processing identifier: roi_0334_slice0454_norm8
#   Original: roi_0334_slice0454_norm8.tif
#   Multi-Otsu: roi_0334_slice0454_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068441
#   Adaptive gradient threshold: 1.600077
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 306632 (72.58%)
#   Total ignored pixels: 315000 (74.56%)
#   Saved: roi_0334_slice0454_norm8.png
#
# [336/661] Processing identifier: roi_0335_slice0455_norm8
#   Original: roi_0335_slice0455_norm8.tif
#   Multi-Otsu: roi_0335_slice0455_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068222
#   Adaptive gradient threshold: 1.592177
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 302699 (71.64%)
#   Total ignored pixels: 312203 (73.89%)
#   Saved: roi_0335_slice0455_norm8.png
#
# [337/661] Processing identifier: roi_0336_slice0456_norm8
#   Original: roi_0336_slice0456_norm8.tif
#   Multi-Otsu: roi_0336_slice0456_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067336
#   Adaptive gradient threshold: 1.583938
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 306453 (72.53%)
#   Total ignored pixels: 315057 (74.57%)
#   Saved: roi_0336_slice0456_norm8.png
#
# [338/661] Processing identifier: roi_0337_slice0457_norm8
#   Original: roi_0337_slice0457_norm8.tif
#   Multi-Otsu: roi_0337_slice0457_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068324
#   Adaptive gradient threshold: 1.596708
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 307860 (72.87%)
#   Total ignored pixels: 315721 (74.73%)
#   Saved: roi_0337_slice0457_norm8.png
#
# [339/661] Processing identifier: roi_0338_slice0458_norm8
#   Original: roi_0338_slice0458_norm8.tif
#   Multi-Otsu: roi_0338_slice0458_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068925
#   Adaptive gradient threshold: 1.600173
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 308089 (72.92%)
#   Total ignored pixels: 316221 (74.85%)
#   Saved: roi_0338_slice0458_norm8.png
#
# [340/661] Processing identifier: roi_0339_slice0459_norm8
#   Original: roi_0339_slice0459_norm8.tif
#   Multi-Otsu: roi_0339_slice0459_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.071234
#   Adaptive gradient threshold: 1.628288
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310625 (73.52%)
#   Total ignored pixels: 317866 (75.23%)
#   Saved: roi_0339_slice0459_norm8.png
#
# [341/661] Processing identifier: roi_0340_slice0460_norm8
#   Original: roi_0340_slice0460_norm8.tif
#   Multi-Otsu: roi_0340_slice0460_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069760
#   Adaptive gradient threshold: 1.611808
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 308160 (72.94%)
#   Total ignored pixels: 316014 (74.80%)
#   Saved: roi_0340_slice0460_norm8.png
#
# [342/661] Processing identifier: roi_0341_slice0461_norm8
#   Original: roi_0341_slice0461_norm8.tif
#   Multi-Otsu: roi_0341_slice0461_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065360
#   Adaptive gradient threshold: 1.559394
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 309124 (73.17%)
#   Total ignored pixels: 317311 (75.10%)
#   Saved: roi_0341_slice0461_norm8.png
#
# [343/661] Processing identifier: roi_0342_slice0462_norm8
#   Original: roi_0342_slice0462_norm8.tif
#   Multi-Otsu: roi_0342_slice0462_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069470
#   Adaptive gradient threshold: 1.611417
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 312481 (73.96%)
#   Total ignored pixels: 320679 (75.90%)
#   Saved: roi_0342_slice0462_norm8.png
#
# [344/661] Processing identifier: roi_0343_slice0463_norm8
#   Original: roi_0343_slice0463_norm8.tif
#   Multi-Otsu: roi_0343_slice0463_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.076672
#   Adaptive gradient threshold: 1.695905
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 312539 (73.97%)
#   Total ignored pixels: 320155 (75.78%)
#   Saved: roi_0343_slice0463_norm8.png
#
# [345/661] Processing identifier: roi_0344_slice0464_norm8
#   Original: roi_0344_slice0464_norm8.tif
#   Multi-Otsu: roi_0344_slice0464_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067927
#   Adaptive gradient threshold: 1.594348
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 308738 (73.07%)
#   Total ignored pixels: 317217 (75.08%)
#   Saved: roi_0344_slice0464_norm8.png
#
# [346/661] Processing identifier: roi_0345_slice0465_norm8
#   Original: roi_0345_slice0465_norm8.tif
#   Multi-Otsu: roi_0345_slice0465_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070942
#   Adaptive gradient threshold: 1.628249
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 307671 (72.82%)
#   Total ignored pixels: 316258 (74.85%)
#   Saved: roi_0345_slice0465_norm8.png
#
# [347/661] Processing identifier: roi_0346_slice0466_norm8
#   Original: roi_0346_slice0466_norm8.tif
#   Multi-Otsu: roi_0346_slice0466_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070196
#   Adaptive gradient threshold: 1.617332
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 308175 (72.94%)
#   Total ignored pixels: 316521 (74.92%)
#   Saved: roi_0346_slice0466_norm8.png
#
# [348/661] Processing identifier: roi_0347_slice0467_norm8
#   Original: roi_0347_slice0467_norm8.tif
#   Multi-Otsu: roi_0347_slice0467_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068218
#   Adaptive gradient threshold: 1.595042
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 305831 (72.39%)
#   Total ignored pixels: 314746 (74.50%)
#   Saved: roi_0347_slice0467_norm8.png
#
# [349/661] Processing identifier: roi_0348_slice0468_norm8
#   Original: roi_0348_slice0468_norm8.tif
#   Multi-Otsu: roi_0348_slice0468_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065599
#   Adaptive gradient threshold: 1.564272
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 304227 (72.01%)
#   Total ignored pixels: 313625 (74.23%)
#   Saved: roi_0348_slice0468_norm8.png
#
# [350/661] Processing identifier: roi_0349_slice0469_norm8
#   Original: roi_0349_slice0469_norm8.tif
#   Multi-Otsu: roi_0349_slice0469_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067442
#   Adaptive gradient threshold: 1.588037
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 303828 (71.91%)
#   Total ignored pixels: 313205 (74.13%)
#   Saved: roi_0349_slice0469_norm8.png
#
# [351/661] Processing identifier: roi_0350_slice0470_norm8
#   Original: roi_0350_slice0470_norm8.tif
#   Multi-Otsu: roi_0350_slice0470_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.063038
#   Adaptive gradient threshold: 1.535694
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 310985 (73.61%)
#   Total ignored pixels: 319065 (75.52%)
#   Saved: roi_0350_slice0470_norm8.png
#
# [352/661] Processing identifier: roi_0351_slice0471_norm8
#   Original: roi_0351_slice0471_norm8.tif
#   Multi-Otsu: roi_0351_slice0471_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068499
#   Adaptive gradient threshold: 1.604848
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 312112 (73.87%)
#   Total ignored pixels: 319875 (75.71%)
#   Saved: roi_0351_slice0471_norm8.png
#
# [353/661] Processing identifier: roi_0352_slice0472_norm8
#   Original: roi_0352_slice0472_norm8.tif
#   Multi-Otsu: roi_0352_slice0472_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.063900
#   Adaptive gradient threshold: 1.548935
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 307427 (72.76%)
#   Total ignored pixels: 316321 (74.87%)
#   Saved: roi_0352_slice0472_norm8.png
#
# [354/661] Processing identifier: roi_0353_slice0473_norm8
#   Original: roi_0353_slice0473_norm8.tif
#   Multi-Otsu: roi_0353_slice0473_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064428
#   Adaptive gradient threshold: 1.557964
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 306193 (72.47%)
#   Total ignored pixels: 315698 (74.72%)
#   Saved: roi_0353_slice0473_norm8.png
#
# [355/661] Processing identifier: roi_0354_slice0474_norm8
#   Original: roi_0354_slice0474_norm8.tif
#   Multi-Otsu: roi_0354_slice0474_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.072290
#   Adaptive gradient threshold: 1.653889
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 313768 (74.26%)
#   Total ignored pixels: 322187 (76.26%)
#   Saved: roi_0354_slice0474_norm8.png
#
# [356/661] Processing identifier: roi_0355_slice0475_norm8
#   Original: roi_0355_slice0475_norm8.tif
#   Multi-Otsu: roi_0355_slice0475_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069722
#   Adaptive gradient threshold: 1.622275
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 307836 (72.86%)
#   Total ignored pixels: 317177 (75.07%)
#   Saved: roi_0355_slice0475_norm8.png
#
# [357/661] Processing identifier: roi_0356_slice0476_norm8
#   Original: roi_0356_slice0476_norm8.tif
#   Multi-Otsu: roi_0356_slice0476_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.066651
#   Adaptive gradient threshold: 1.582099
#   High variance pixels: 42249 (10.00%)
#   High gradient pixels: 42245 (10.00%)
#   Pore↔solid boundary pixels: 306776 (72.61%)
#   Total ignored pixels: 315700 (74.72%)
#   Saved: roi_0356_slice0476_norm8.png
#
# [358/661] Processing identifier: roi_0357_slice0477_norm8
#   Original: roi_0357_slice0477_norm8.tif
#   Multi-Otsu: roi_0357_slice0477_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067983
#   Adaptive gradient threshold: 1.598202
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 305388 (72.28%)
#   Total ignored pixels: 314861 (74.52%)
#   Saved: roi_0357_slice0477_norm8.png
#
# [359/661] Processing identifier: roi_0358_slice0478_norm8
#   Original: roi_0358_slice0478_norm8.tif
#   Multi-Otsu: roi_0358_slice0478_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070038
#   Adaptive gradient threshold: 1.623212
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 307044 (72.67%)
#   Total ignored pixels: 316090 (74.81%)
#   Saved: roi_0358_slice0478_norm8.png
#
# [360/661] Processing identifier: roi_0359_slice0479_norm8
#   Original: roi_0359_slice0479_norm8.tif
#   Multi-Otsu: roi_0359_slice0479_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.071328
#   Adaptive gradient threshold: 1.636343
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310577 (73.51%)
#   Total ignored pixels: 318967 (75.50%)
#   Saved: roi_0359_slice0479_norm8.png
#
# [361/661] Processing identifier: roi_0360_slice0480_norm8
#   Original: roi_0360_slice0480_norm8.tif
#   Multi-Otsu: roi_0360_slice0480_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070686
#   Adaptive gradient threshold: 1.622952
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 312219 (73.90%)
#   Total ignored pixels: 319883 (75.71%)
#   Saved: roi_0360_slice0480_norm8.png
#
# [362/661] Processing identifier: roi_0361_slice0481_norm8
#   Original: roi_0361_slice0481_norm8.tif
#   Multi-Otsu: roi_0361_slice0481_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068820
#   Adaptive gradient threshold: 1.599481
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 307093 (72.68%)
#   Total ignored pixels: 316099 (74.82%)
#   Saved: roi_0361_slice0481_norm8.png
#
# [363/661] Processing identifier: roi_0362_slice0482_norm8
#   Original: roi_0362_slice0482_norm8.tif
#   Multi-Otsu: roi_0362_slice0482_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.069116
#   Adaptive gradient threshold: 1.601630
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 305081 (72.21%)
#   Total ignored pixels: 313971 (74.31%)
#   Saved: roi_0362_slice0482_norm8.png
#
# [364/661] Processing identifier: roi_0363_slice0483_norm8
#   Original: roi_0363_slice0483_norm8.tif
#   Multi-Otsu: roi_0363_slice0483_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064829
#   Adaptive gradient threshold: 1.553040
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 302266 (71.54%)
#   Total ignored pixels: 311364 (73.70%)
#   Saved: roi_0363_slice0483_norm8.png
#
# [365/661] Processing identifier: roi_0364_slice0484_norm8
#   Original: roi_0364_slice0484_norm8.tif
#   Multi-Otsu: roi_0364_slice0484_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067479
#   Adaptive gradient threshold: 1.579278
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 307033 (72.67%)
#   Total ignored pixels: 315475 (74.67%)
#   Saved: roi_0364_slice0484_norm8.png
#
# [366/661] Processing identifier: roi_0365_slice0485_norm8
#   Original: roi_0365_slice0485_norm8.tif
#   Multi-Otsu: roi_0365_slice0485_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065418
#   Adaptive gradient threshold: 1.548998
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 306801 (72.62%)
#   Total ignored pixels: 314789 (74.51%)
#   Saved: roi_0365_slice0485_norm8.png
#
# [367/661] Processing identifier: roi_0366_slice0486_norm8
#   Original: roi_0366_slice0486_norm8.tif
#   Multi-Otsu: roi_0366_slice0486_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067045
#   Adaptive gradient threshold: 1.568284
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 305168 (72.23%)
#   Total ignored pixels: 314158 (74.36%)
#   Saved: roi_0366_slice0486_norm8.png
#
# [368/661] Processing identifier: roi_0367_slice0487_norm8
#   Original: roi_0367_slice0487_norm8.tif
#   Multi-Otsu: roi_0367_slice0487_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064357
#   Adaptive gradient threshold: 1.535183
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 300570 (71.14%)
#   Total ignored pixels: 310150 (73.41%)
#   Saved: roi_0367_slice0487_norm8.png
#
# [369/661] Processing identifier: roi_0368_slice0488_norm8
#   Original: roi_0368_slice0488_norm8.tif
#   Multi-Otsu: roi_0368_slice0488_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.070765
#   Adaptive gradient threshold: 1.607556
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 306123 (72.46%)
#   Total ignored pixels: 314926 (74.54%)
#   Saved: roi_0368_slice0488_norm8.png
#
# [370/661] Processing identifier: roi_0369_slice0489_norm8
#   Original: roi_0369_slice0489_norm8.tif
#   Multi-Otsu: roi_0369_slice0489_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062964
#   Adaptive gradient threshold: 1.517247
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 307295 (72.73%)
#   Total ignored pixels: 315524 (74.68%)
#   Saved: roi_0369_slice0489_norm8.png
#
# [371/661] Processing identifier: roi_0370_slice0490_norm8
#   Original: roi_0370_slice0490_norm8.tif
#   Multi-Otsu: roi_0370_slice0490_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.072038
#   Adaptive gradient threshold: 1.624306
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 311335 (73.69%)
#   Total ignored pixels: 318928 (75.49%)
#   Saved: roi_0370_slice0490_norm8.png
#
# [372/661] Processing identifier: roi_0371_slice0491_norm8
#   Original: roi_0371_slice0491_norm8.tif
#   Multi-Otsu: roi_0371_slice0491_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067803
#   Adaptive gradient threshold: 1.577982
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310091 (73.39%)
#   Total ignored pixels: 318667 (75.42%)
#   Saved: roi_0371_slice0491_norm8.png
#
# [373/661] Processing identifier: roi_0372_slice0492_norm8
#   Original: roi_0372_slice0492_norm8.tif
#   Multi-Otsu: roi_0372_slice0492_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064762
#   Adaptive gradient threshold: 1.542937
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 307684 (72.82%)
#   Total ignored pixels: 316643 (74.95%)
#   Saved: roi_0372_slice0492_norm8.png
#
# [374/661] Processing identifier: roi_0373_slice0493_norm8
#   Original: roi_0373_slice0493_norm8.tif
#   Multi-Otsu: roi_0373_slice0493_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064712
#   Adaptive gradient threshold: 1.541274
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 310674 (73.53%)
#   Total ignored pixels: 318937 (75.49%)
#   Saved: roi_0373_slice0493_norm8.png
#
# [375/661] Processing identifier: roi_0374_slice0494_norm8
#   Original: roi_0374_slice0494_norm8.tif
#   Multi-Otsu: roi_0374_slice0494_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065256
#   Adaptive gradient threshold: 1.544464
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 311074 (73.63%)
#   Total ignored pixels: 319123 (75.53%)
#   Saved: roi_0374_slice0494_norm8.png
#
# [376/661] Processing identifier: roi_0375_slice0495_norm8
#   Original: roi_0375_slice0495_norm8.tif
#   Multi-Otsu: roi_0375_slice0495_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067375
#   Adaptive gradient threshold: 1.569539
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 309672 (73.30%)
#   Total ignored pixels: 318402 (75.36%)
#   Saved: roi_0375_slice0495_norm8.png
#
# [377/661] Processing identifier: roi_0376_slice0496_norm8
#   Original: roi_0376_slice0496_norm8.tif
#   Multi-Otsu: roi_0376_slice0496_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067094
#   Adaptive gradient threshold: 1.567156
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 310699 (73.54%)
#   Total ignored pixels: 318864 (75.47%)
#   Saved: roi_0376_slice0496_norm8.png
#
# [378/661] Processing identifier: roi_0377_slice0497_norm8
#   Original: roi_0377_slice0497_norm8.tif
#   Multi-Otsu: roi_0377_slice0497_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.063411
#   Adaptive gradient threshold: 1.522880
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 308998 (73.14%)
#   Total ignored pixels: 317353 (75.11%)
#   Saved: roi_0377_slice0497_norm8.png
#
# [379/661] Processing identifier: roi_0378_slice0498_norm8
#   Original: roi_0378_slice0498_norm8.tif
#   Multi-Otsu: roi_0378_slice0498_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067569
#   Adaptive gradient threshold: 1.571860
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 311480 (73.72%)
#   Total ignored pixels: 319579 (75.64%)
#   Saved: roi_0378_slice0498_norm8.png
#
# [380/661] Processing identifier: roi_0379_slice0499_norm8
#   Original: roi_0379_slice0499_norm8.tif
#   Multi-Otsu: roi_0379_slice0499_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062178
#   Adaptive gradient threshold: 1.504329
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 313445 (74.19%)
#   Total ignored pixels: 321342 (76.06%)
#   Saved: roi_0379_slice0499_norm8.png
#
# [381/661] Processing identifier: roi_0380_slice0500_norm8
#   Original: roi_0380_slice0500_norm8.tif
#   Multi-Otsu: roi_0380_slice0500_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.065727
#   Adaptive gradient threshold: 1.549551
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 311776 (73.79%)
#   Total ignored pixels: 320182 (75.78%)
#   Saved: roi_0380_slice0500_norm8.png
#
# [382/661] Processing identifier: roi_0381_slice0501_norm8
#   Original: roi_0381_slice0501_norm8.tif
#   Multi-Otsu: roi_0381_slice0501_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.064639
#   Adaptive gradient threshold: 1.532225
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 310115 (73.40%)
#   Total ignored pixels: 317766 (75.21%)
#   Saved: roi_0381_slice0501_norm8.png
#
# [383/661] Processing identifier: roi_0382_slice0502_norm8
#   Original: roi_0382_slice0502_norm8.tif
#   Multi-Otsu: roi_0382_slice0502_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.066887
#   Adaptive gradient threshold: 1.558023
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 307526 (72.79%)
#   Total ignored pixels: 315745 (74.73%)
#   Saved: roi_0382_slice0502_norm8.png
#
# [384/661] Processing identifier: roi_0383_slice0503_norm8
#   Original: roi_0383_slice0503_norm8.tif
#   Multi-Otsu: roi_0383_slice0503_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.063242
#   Adaptive gradient threshold: 1.511957
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 302429 (71.58%)
#   Total ignored pixels: 311277 (73.68%)
#   Saved: roi_0383_slice0503_norm8.png
#
# [385/661] Processing identifier: roi_0384_slice0504_norm8
#   Original: roi_0384_slice0504_norm8.tif
#   Multi-Otsu: roi_0384_slice0504_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067212
#   Adaptive gradient threshold: 1.563339
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 303080 (71.73%)
#   Total ignored pixels: 312075 (73.86%)
#   Saved: roi_0384_slice0504_norm8.png
#
# [386/661] Processing identifier: roi_0385_slice0505_norm8
#   Original: roi_0385_slice0505_norm8.tif
#   Multi-Otsu: roi_0385_slice0505_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062866
#   Adaptive gradient threshold: 1.512178
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 302437 (71.58%)
#   Total ignored pixels: 311145 (73.64%)
#   Saved: roi_0385_slice0505_norm8.png
#
# [387/661] Processing identifier: roi_0386_slice0506_norm8
#   Original: roi_0386_slice0506_norm8.tif
#   Multi-Otsu: roi_0386_slice0506_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.066729
#   Adaptive gradient threshold: 1.560863
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 304665 (72.11%)
#   Total ignored pixels: 313179 (74.13%)
#   Saved: roi_0386_slice0506_norm8.png
#
# [388/661] Processing identifier: roi_0387_slice0507_norm8
#   Original: roi_0387_slice0507_norm8.tif
#   Multi-Otsu: roi_0387_slice0507_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.068153
#   Adaptive gradient threshold: 1.577719
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 305604 (72.33%)
#   Total ignored pixels: 313620 (74.23%)
#   Saved: roi_0387_slice0507_norm8.png
#
# [389/661] Processing identifier: roi_0388_slice0508_norm8
#   Original: roi_0388_slice0508_norm8.tif
#   Multi-Otsu: roi_0388_slice0508_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.067019
#   Adaptive gradient threshold: 1.560627
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 307382 (72.75%)
#   Total ignored pixels: 315633 (74.71%)
#   Saved: roi_0388_slice0508_norm8.png
#
# [390/661] Processing identifier: roi_0389_slice0509_norm8
#   Original: roi_0389_slice0509_norm8.tif
#   Multi-Otsu: roi_0389_slice0509_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
# ...
# [634/661] Processing identifier: roi_0633_slice0753_norm8
#   Original: roi_0633_slice0753_norm8.tif
#   Multi-Otsu: roi_0633_slice0753_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.061503
#   Adaptive gradient threshold: 1.459793
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 296887 (70.27%)
#   Total ignored pixels: 305976 (72.42%)
#   Saved: roi_0633_slice0753_norm8.png
#
# [635/661] Processing identifier: roi_0634_slice0754_norm8
#   Original: roi_0634_slice0754_norm8.tif
#   Multi-Otsu: roi_0634_slice0754_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062029
#   Adaptive gradient threshold: 1.467673
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 294306 (69.66%)
#   Total ignored pixels: 303840 (71.91%)
#   Saved: roi_0634_slice0754_norm8.png
#
# [636/661] Processing identifier: roi_0635_slice0755_norm8
#   Original: roi_0635_slice0755_norm8.tif
#   Multi-Otsu: roi_0635_slice0755_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.059363
#   Adaptive gradient threshold: 1.430948
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 290999 (68.88%)
#   Total ignored pixels: 301100 (71.27%)
#   Saved: roi_0635_slice0755_norm8.png
#
# [637/661] Processing identifier: roi_0636_slice0756_norm8
#   Original: roi_0636_slice0756_norm8.tif
#   Multi-Otsu: roi_0636_slice0756_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.059876
#   Adaptive gradient threshold: 1.435626
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 292921 (69.33%)
#   Total ignored pixels: 301690 (71.41%)
#   Saved: roi_0636_slice0756_norm8.png
#
# [638/661] Processing identifier: roi_0637_slice0757_norm8
#   Original: roi_0637_slice0757_norm8.tif
#   Multi-Otsu: roi_0637_slice0757_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.057223
#   Adaptive gradient threshold: 1.409122
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 292915 (69.33%)
#   Total ignored pixels: 302183 (71.52%)
#   Saved: roi_0637_slice0757_norm8.png
#
# [639/661] Processing identifier: roi_0638_slice0758_norm8
#   Original: roi_0638_slice0758_norm8.tif
#   Multi-Otsu: roi_0638_slice0758_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060140
#   Adaptive gradient threshold: 1.445969
#   High variance pixels: 42249 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 294448 (69.69%)
#   Total ignored pixels: 303355 (71.80%)
#   Saved: roi_0638_slice0758_norm8.png
#
# [640/661] Processing identifier: roi_0639_slice0759_norm8
#   Original: roi_0639_slice0759_norm8.tif
#   Multi-Otsu: roi_0639_slice0759_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.057508
#   Adaptive gradient threshold: 1.412309
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 295859 (70.03%)
#   Total ignored pixels: 305296 (72.26%)
#   Saved: roi_0639_slice0759_norm8.png
#
# [641/661] Processing identifier: roi_0640_slice0760_norm8
#   Original: roi_0640_slice0760_norm8.tif
#   Multi-Otsu: roi_0640_slice0760_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062072
#   Adaptive gradient threshold: 1.469338
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 300363 (71.09%)
#   Total ignored pixels: 310595 (73.51%)
#   Saved: roi_0640_slice0760_norm8.png
#
# [642/661] Processing identifier: roi_0641_slice0761_norm8
#   Original: roi_0641_slice0761_norm8.tif
#   Multi-Otsu: roi_0641_slice0761_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.062220
#   Adaptive gradient threshold: 1.474187
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 298069 (70.55%)
#   Total ignored pixels: 308236 (72.96%)
#   Saved: roi_0641_slice0761_norm8.png
#
# [643/661] Processing identifier: roi_0642_slice0762_norm8
#   Original: roi_0642_slice0762_norm8.tif
#   Multi-Otsu: roi_0642_slice0762_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.059078
#   Adaptive gradient threshold: 1.436044
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 298988 (70.77%)
#   Total ignored pixels: 307784 (72.85%)
#   Saved: roi_0642_slice0762_norm8.png
#
# [644/661] Processing identifier: roi_0643_slice0763_norm8
#   Original: roi_0643_slice0763_norm8.tif
#   Multi-Otsu: roi_0643_slice0763_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060512
#   Adaptive gradient threshold: 1.447503
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 298071 (70.55%)
#   Total ignored pixels: 306007 (72.43%)
#   Saved: roi_0643_slice0763_norm8.png
#
# [645/661] Processing identifier: roi_0644_slice0764_norm8
#   Original: roi_0644_slice0764_norm8.tif
#   Multi-Otsu: roi_0644_slice0764_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.058738
#   Adaptive gradient threshold: 1.425910
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 293690 (69.51%)
#   Total ignored pixels: 303662 (71.87%)
#   Saved: roi_0644_slice0764_norm8.png
#
# [646/661] Processing identifier: roi_0645_slice0765_norm8
#   Original: roi_0645_slice0765_norm8.tif
#   Multi-Otsu: roi_0645_slice0765_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.061607
#   Adaptive gradient threshold: 1.461857
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 293951 (69.57%)
#   Total ignored pixels: 303532 (71.84%)
#   Saved: roi_0645_slice0765_norm8.png
#
# [647/661] Processing identifier: roi_0646_slice0766_norm8
#   Original: roi_0646_slice0766_norm8.tif
#   Multi-Otsu: roi_0646_slice0766_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060925
#   Adaptive gradient threshold: 1.452156
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42244 (10.00%)
#   Pore↔solid boundary pixels: 294221 (69.64%)
#   Total ignored pixels: 303672 (71.88%)
#   Saved: roi_0646_slice0766_norm8.png
#
# [648/661] Processing identifier: roi_0647_slice0767_norm8
#   Original: roi_0647_slice0767_norm8.tif
#   Multi-Otsu: roi_0647_slice0767_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.059084
#   Adaptive gradient threshold: 1.428102
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 296611 (70.20%)
#   Total ignored pixels: 306964 (72.65%)
#   Saved: roi_0647_slice0767_norm8.png
#
# [649/661] Processing identifier: roi_0648_slice0768_norm8
#   Original: roi_0648_slice0768_norm8.tif
#   Multi-Otsu: roi_0648_slice0768_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.057372
#   Adaptive gradient threshold: 1.408908
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 295755 (70.00%)
#   Total ignored pixels: 306726 (72.60%)
#   Saved: roi_0648_slice0768_norm8.png
#
# [650/661] Processing identifier: roi_0649_slice0769_norm8
#   Original: roi_0649_slice0769_norm8.tif
#   Multi-Otsu: roi_0649_slice0769_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060313
#   Adaptive gradient threshold: 1.445948
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 297716 (70.47%)
#   Total ignored pixels: 307740 (72.84%)
#   Saved: roi_0649_slice0769_norm8.png
#
# [651/661] Processing identifier: roi_0650_slice0770_norm8
#   Original: roi_0650_slice0770_norm8.tif
#   Multi-Otsu: roi_0650_slice0770_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.066440
#   Adaptive gradient threshold: 1.519597
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 299502 (70.89%)
#   Total ignored pixels: 308461 (73.01%)
#   Saved: roi_0650_slice0770_norm8.png
#
# [652/661] Processing identifier: roi_0651_slice0771_norm8
#   Original: roi_0651_slice0771_norm8.tif
#   Multi-Otsu: roi_0651_slice0771_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.055788
#   Adaptive gradient threshold: 1.393134
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 297612 (70.44%)
#   Total ignored pixels: 307262 (72.72%)
#   Saved: roi_0651_slice0771_norm8.png
#
# [653/661] Processing identifier: roi_0652_slice0772_norm8
#   Original: roi_0652_slice0772_norm8.tif
#   Multi-Otsu: roi_0652_slice0772_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060732
#   Adaptive gradient threshold: 1.457231
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42247 (10.00%)
#   Pore↔solid boundary pixels: 296719 (70.23%)
#   Total ignored pixels: 305197 (72.24%)
#   Saved: roi_0652_slice0772_norm8.png
#
# [654/661] Processing identifier: roi_0653_slice0773_norm8
#   Original: roi_0653_slice0773_norm8.tif
#   Multi-Otsu: roi_0653_slice0773_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.059440
#   Adaptive gradient threshold: 1.441885
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 297211 (70.35%)
#   Total ignored pixels: 306562 (72.56%)
#   Saved: roi_0653_slice0773_norm8.png
#
# [655/661] Processing identifier: roi_0654_slice0774_norm8
#   Original: roi_0654_slice0774_norm8.tif
#   Multi-Otsu: roi_0654_slice0774_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060927
#   Adaptive gradient threshold: 1.459340
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 292884 (69.32%)
#   Total ignored pixels: 302303 (71.55%)
#   Saved: roi_0654_slice0774_norm8.png
#
# [656/661] Processing identifier: roi_0655_slice0775_norm8
#   Original: roi_0655_slice0775_norm8.tif
#   Multi-Otsu: roi_0655_slice0775_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060863
#   Adaptive gradient threshold: 1.454907
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 293489 (69.46%)
#   Total ignored pixels: 303887 (71.93%)
#   Saved: roi_0655_slice0775_norm8.png
#
# [657/661] Processing identifier: roi_0656_slice0776_norm8
#   Original: roi_0656_slice0776_norm8.tif
#   Multi-Otsu: roi_0656_slice0776_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.060217
#   Adaptive gradient threshold: 1.447064
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42246 (10.00%)
#   Pore↔solid boundary pixels: 292395 (69.21%)
#   Total ignored pixels: 301391 (71.34%)
#   Saved: roi_0656_slice0776_norm8.png
#
# [658/661] Processing identifier: roi_0657_slice0777_norm8
#   Original: roi_0657_slice0777_norm8.tif
#   Multi-Otsu: roi_0657_slice0777_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.057295
#   Adaptive gradient threshold: 1.411591
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42248 (10.00%)
#   Pore↔solid boundary pixels: 294915 (69.80%)
#   Total ignored pixels: 304259 (72.01%)
#   Saved: roi_0657_slice0777_norm8.png
#
# [659/661] Processing identifier: roi_0658_slice0778_norm8
#   Original: roi_0658_slice0778_norm8.tif
#   Multi-Otsu: roi_0658_slice0778_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.057376
#   Adaptive gradient threshold: 1.411397
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 291918 (69.09%)
#   Total ignored pixels: 301940 (71.47%)
#   Saved: roi_0658_slice0778_norm8.png
#
# [660/661] Processing identifier: roi_0659_slice0779_norm8
#   Original: roi_0659_slice0779_norm8.tif
#   Multi-Otsu: roi_0659_slice0779_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.059250
#   Adaptive gradient threshold: 1.436526
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42250 (10.00%)
#   Pore↔solid boundary pixels: 290693 (68.80%)
#   Total ignored pixels: 300357 (71.09%)
#   Saved: roi_0659_slice0779_norm8.png
#
# [661/661] Processing identifier: roi_0660_slice0780_norm8
#   Original: roi_0660_slice0780_norm8.tif
#   Multi-Otsu: roi_0660_slice0780_norm8_pores_class0plus1.png
#   Computing local variance... done
#   Computing gradient magnitude... done
#   Computing pore↔solid boundary mask... done
#   Adaptive variance threshold: 0.056393
#   Adaptive gradient threshold: 1.404119
#   High variance pixels: 42250 (10.00%)
#   High gradient pixels: 42249 (10.00%)
#   Pore↔solid boundary pixels: 295319 (69.90%)
#   Total ignored pixels: 304808 (72.14%)
#   Saved: roi_0660_slice0780_norm8.png
#
# ============================================================
# COMPLETED: Processed 661 image pairs
# Output directory: /content/drive/MyDrive/soil_microCT_images/ROI/weak_supervision_masks/rehovot_ROI_8bit
# ============================================================
