# %%
from pathlib import Path
import numpy as np
import tifffile as tiff


# =========================
# SETTINGS (CHANGE THESE)
# =========================

INPUT_DIR = r"/content/drive/MyDrive/soil_microCT_images/ROI/mishmar_hanegev_maoz_ROI_16bit"


OUTPUT_DIR = r"/content/drive/MyDrive/soil_microCT_images/ROI/mishmar_hanegev_maoz_ROI_8bit"


SUFFIX = "_norm8"


TO8_METHOD = "percentile"
P_LOW = 0.5
P_HIGH = 99.5


def to_uint8(
    img: np.ndarray,
    method: str = "percentile",
    p_low: float = 0.5,
    p_high: float = 99.5
) -> np.ndarray:
    """
    Convert image/stack to uint8 [0..255].
    method:
      - "percentile": robust scaling using percentiles
      - "minmax": linear scaling using min/max
      - "divide256": uint16 -> uint8 by /256 (fast, often worse)
    """
    if img.dtype == np.uint8:
        return img

    x = img.astype(np.float32)

    if method == "divide256":
        x = np.clip(x / 256.0, 0, 255)
        return x.astype(np.uint8)

    if method == "minmax":
        mn = float(np.min(x))
        mx = float(np.max(x))
    elif method == "percentile":
        mn = float(np.percentile(x, p_low))
        mx = float(np.percentile(x, p_high))
    else:
        raise ValueError("Unknown method. Use: 'percentile', 'minmax', 'divide256'.")

    if mx <= mn:
        return np.zeros_like(x, dtype=np.uint8)

    x = (x - mn) * (255.0 / (mx - mn))
    x = np.clip(x, 0, 255)
    return x.astype(np.uint8)


def detect_mode_above_100(img: np.ndarray, low: int = 100, high: int = 254) -> int:
    """
    img: TIFF ndarray (2D или 3D stack).
    Возвращает mode значений в диапазоне [low, high] для 8-bit изображения.
    """
    if img.dtype != np.uint8:
        raise ValueError(f"Expected uint8 image (0-255). Got dtype={img.dtype}")

    flat = img.ravel()
    mask = (flat >= low) & (flat <= high)
    if not np.any(mask):
        return 0

    counts = np.bincount(flat[mask], minlength=256)
    mode = int(np.argmax(counts[low:high + 1]) + low)
    return mode


def normalize_stack_to_mode_200(img: np.ndarray, mode: int, target: float = 200.0) -> np.ndarray:
    """
    Multiply by factor=target/mode (как ImageJ Multiply...) и clip к 0..255.
    """
    if mode <= 0:
        return img

    factor = target / float(mode)
    out = img.astype(np.float32) * factor
    out = np.clip(out, 0, 255).astype(np.uint8)
    return out


def process_folder(
    input_dir: str,
    output_dir: str,
    suffix: str = "_norm8",
    to8_method: str = "percentile",
    p_low: float = 0.5,
    p_high: float = 99.5
) -> None:
    in_path = Path(input_dir)
    if not in_path.exists():
        raise FileNotFoundError(f"INPUT_DIR not found: {in_path}")

    out_path = Path(output_dir)
    out_path.mkdir(parents=True, exist_ok=True)

    tif_files = sorted([p for p in in_path.iterdir()
                        if p.is_file() and p.suffix.lower() in {".tif", ".tiff"}])

    if not tif_files:
        print(f"No TIFF files found in: {in_path}")
        return

    print(f"Input folder : {in_path}")
    print(f"Output folder: {out_path}")
    print(f"Found {len(tif_files)} TIFF file(s).")
    print("-" * 60)

    for p in tif_files:
        img = tiff.imread(p)  # 2D или 3D stack
        print(f"{p.name}: dtype={img.dtype}, shape={img.shape}")

        # Convert to 8-bit if needed
        img8 = to_uint8(img, method=to8_method, p_low=p_low, p_high=p_high)
        print(f" -> uint8: dtype={img8.dtype}, min={img8.min()}, max={img8.max()}")

        mode = detect_mode_above_100(img8, low=100, high=254)
        print(f" -> mode(100..254)={mode}")

        norm = normalize_stack_to_mode_200(img8, mode, target=200.0)

        out_name = f"{p.stem}{suffix}{p.suffix}"
        out_file = out_path / out_name

        # Save as uint8 TIFF (stack remains stack)
        tiff.imwrite(out_file, norm)

        print(f" -> saved: {out_file.name}")
        print("-" * 60)

    print("Done.")


if __name__ == "__main__":
    process_folder(
        input_dir=INPUT_DIR,
        output_dir=OUTPUT_DIR,
        suffix=SUFFIX,
        to8_method=TO8_METHOD,
        p_low=P_LOW,
        p_high=P_HIGH
    )
# Out:
# Streaming output truncated to the last 5000 lines.
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0203_slice0278_norm8.tif
# ------------------------------------------------------------
# roi_0204_slice0279.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0204_slice0279_norm8.tif
# ------------------------------------------------------------
# roi_0205_slice0280.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0205_slice0280_norm8.tif
# ------------------------------------------------------------
# roi_0206_slice0281.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0206_slice0281_norm8.tif
# ------------------------------------------------------------
# roi_0207_slice0282.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0207_slice0282_norm8.tif
# ------------------------------------------------------------
# roi_0208_slice0283.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0208_slice0283_norm8.tif
# ------------------------------------------------------------
# roi_0209_slice0284.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0209_slice0284_norm8.tif
# ------------------------------------------------------------
# roi_0210_slice0285.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0210_slice0285_norm8.tif
# ------------------------------------------------------------
# roi_0211_slice0286.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0211_slice0286_norm8.tif
# ------------------------------------------------------------
# roi_0212_slice0287.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0212_slice0287_norm8.tif
# ------------------------------------------------------------
# roi_0213_slice0288.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0213_slice0288_norm8.tif
# ------------------------------------------------------------
# roi_0214_slice0289.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=142
#  -> saved: roi_0214_slice0289_norm8.tif
# ------------------------------------------------------------
# roi_0215_slice0290.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0215_slice0290_norm8.tif
# ------------------------------------------------------------
# roi_0216_slice0291.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0216_slice0291_norm8.tif
# ------------------------------------------------------------
# roi_0217_slice0292.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0217_slice0292_norm8.tif
# ------------------------------------------------------------
# roi_0218_slice0293.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0218_slice0293_norm8.tif
# ------------------------------------------------------------
# roi_0219_slice0294.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0219_slice0294_norm8.tif
# ------------------------------------------------------------
# roi_0220_slice0295.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0220_slice0295_norm8.tif
# ------------------------------------------------------------
# roi_0221_slice0296.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0221_slice0296_norm8.tif
# ------------------------------------------------------------
# roi_0222_slice0297.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0222_slice0297_norm8.tif
# ------------------------------------------------------------
# roi_0223_slice0298.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0223_slice0298_norm8.tif
# ------------------------------------------------------------
# roi_0224_slice0299.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0224_slice0299_norm8.tif
# ------------------------------------------------------------
# roi_0225_slice0300.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0225_slice0300_norm8.tif
# ------------------------------------------------------------
# roi_0226_slice0301.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0226_slice0301_norm8.tif
# ------------------------------------------------------------
# roi_0227_slice0302.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0227_slice0302_norm8.tif
# ------------------------------------------------------------
# roi_0228_slice0303.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0228_slice0303_norm8.tif
# ------------------------------------------------------------
# roi_0229_slice0304.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=147
#  -> saved: roi_0229_slice0304_norm8.tif
# ------------------------------------------------------------
# roi_0230_slice0305.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=142
#  -> saved: roi_0230_slice0305_norm8.tif
# ------------------------------------------------------------
# roi_0231_slice0306.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=145
#  -> saved: roi_0231_slice0306_norm8.tif
# ------------------------------------------------------------
# roi_0232_slice0307.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=143
#  -> saved: roi_0232_slice0307_norm8.tif
# ------------------------------------------------------------
# roi_0233_slice0308.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=145
#  -> saved: roi_0233_slice0308_norm8.tif
# ------------------------------------------------------------
# roi_0234_slice0309.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0234_slice0309_norm8.tif
# ------------------------------------------------------------
# roi_0235_slice0310.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=142
#  -> saved: roi_0235_slice0310_norm8.tif
# ------------------------------------------------------------
# roi_0236_slice0311.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=140
#  -> saved: roi_0236_slice0311_norm8.tif
# ------------------------------------------------------------
# roi_0237_slice0312.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=143
#  -> saved: roi_0237_slice0312_norm8.tif
# ------------------------------------------------------------
# roi_0238_slice0313.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0238_slice0313_norm8.tif
# ------------------------------------------------------------
# roi_0239_slice0314.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0239_slice0314_norm8.tif
# ------------------------------------------------------------
# roi_0240_slice0315.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0240_slice0315_norm8.tif
# ------------------------------------------------------------
# roi_0241_slice0316.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0241_slice0316_norm8.tif
# ------------------------------------------------------------
# roi_0242_slice0317.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0242_slice0317_norm8.tif
# ------------------------------------------------------------
# roi_0243_slice0318.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0243_slice0318_norm8.tif
# ------------------------------------------------------------
# roi_0244_slice0319.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=138
#  -> saved: roi_0244_slice0319_norm8.tif
# ------------------------------------------------------------
# roi_0245_slice0320.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=140
#  -> saved: roi_0245_slice0320_norm8.tif
# ------------------------------------------------------------
# roi_0246_slice0321.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0246_slice0321_norm8.tif
# ------------------------------------------------------------
# roi_0247_slice0322.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0247_slice0322_norm8.tif
# ------------------------------------------------------------
# roi_0248_slice0323.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0248_slice0323_norm8.tif
# ------------------------------------------------------------
# roi_0249_slice0324.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0249_slice0324_norm8.tif
# ------------------------------------------------------------
# roi_0250_slice0325.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0250_slice0325_norm8.tif
# ------------------------------------------------------------
# roi_0251_slice0326.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0251_slice0326_norm8.tif
# ------------------------------------------------------------
# roi_0252_slice0327.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0252_slice0327_norm8.tif
# ------------------------------------------------------------
# roi_0253_slice0328.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0253_slice0328_norm8.tif
# ------------------------------------------------------------
# roi_0254_slice0329.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0254_slice0329_norm8.tif
# ------------------------------------------------------------
# roi_0255_slice0330.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0255_slice0330_norm8.tif
# ------------------------------------------------------------
# roi_0256_slice0331.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0256_slice0331_norm8.tif
# ------------------------------------------------------------
# roi_0257_slice0332.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0257_slice0332_norm8.tif
# ------------------------------------------------------------
# roi_0258_slice0333.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0258_slice0333_norm8.tif
# ------------------------------------------------------------
# roi_0259_slice0334.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0259_slice0334_norm8.tif
# ------------------------------------------------------------
# roi_0260_slice0335.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0260_slice0335_norm8.tif
# ------------------------------------------------------------
# roi_0261_slice0336.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0261_slice0336_norm8.tif
# ------------------------------------------------------------
# roi_0262_slice0337.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0262_slice0337_norm8.tif
# ------------------------------------------------------------
# roi_0263_slice0338.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0263_slice0338_norm8.tif
# ------------------------------------------------------------
# roi_0264_slice0339.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0264_slice0339_norm8.tif
# ------------------------------------------------------------
# roi_0265_slice0340.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0265_slice0340_norm8.tif
# ------------------------------------------------------------
# roi_0266_slice0341.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0266_slice0341_norm8.tif
# ------------------------------------------------------------
# roi_0267_slice0342.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_0267_slice0342_norm8.tif
# ------------------------------------------------------------
# roi_0268_slice0343.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_0268_slice0343_norm8.tif
# ------------------------------------------------------------
# roi_0269_slice0344.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_0269_slice0344_norm8.tif
# ------------------------------------------------------------
# roi_0270_slice0345.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0270_slice0345_norm8.tif
# ------------------------------------------------------------
# roi_0271_slice0346.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0271_slice0346_norm8.tif
# ------------------------------------------------------------
# roi_0272_slice0347.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0272_slice0347_norm8.tif
# ------------------------------------------------------------
# roi_0273_slice0348.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0273_slice0348_norm8.tif
# ------------------------------------------------------------
# roi_0274_slice0349.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0274_slice0349_norm8.tif
# ------------------------------------------------------------
# roi_0275_slice0350.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0275_slice0350_norm8.tif
# ------------------------------------------------------------
# roi_0276_slice0351.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0276_slice0351_norm8.tif
# ------------------------------------------------------------
# roi_0277_slice0352.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0277_slice0352_norm8.tif
# ------------------------------------------------------------
# roi_0278_slice0353.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0278_slice0353_norm8.tif
# ------------------------------------------------------------
# roi_0279_slice0354.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0279_slice0354_norm8.tif
# ------------------------------------------------------------
# roi_0280_slice0355.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0280_slice0355_norm8.tif
# ------------------------------------------------------------
# roi_0281_slice0356.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0281_slice0356_norm8.tif
# ------------------------------------------------------------
# roi_0282_slice0357.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0282_slice0357_norm8.tif
# ------------------------------------------------------------
# roi_0283_slice0358.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0283_slice0358_norm8.tif
# ------------------------------------------------------------
# roi_0284_slice0359.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0284_slice0359_norm8.tif
# ------------------------------------------------------------
# roi_0285_slice0360.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0285_slice0360_norm8.tif
# ------------------------------------------------------------
# roi_0286_slice0361.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0286_slice0361_norm8.tif
# ------------------------------------------------------------
# roi_0287_slice0362.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0287_slice0362_norm8.tif
# ------------------------------------------------------------
# roi_0288_slice0363.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0288_slice0363_norm8.tif
# ------------------------------------------------------------
# roi_0289_slice0364.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0289_slice0364_norm8.tif
# ------------------------------------------------------------
# roi_0290_slice0365.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0290_slice0365_norm8.tif
# ------------------------------------------------------------
# roi_0291_slice0366.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0291_slice0366_norm8.tif
# ------------------------------------------------------------
# roi_0292_slice0367.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0292_slice0367_norm8.tif
# ------------------------------------------------------------
# roi_0293_slice0368.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0293_slice0368_norm8.tif
# ------------------------------------------------------------
# roi_0294_slice0369.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0294_slice0369_norm8.tif
# ------------------------------------------------------------
# roi_0295_slice0370.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0295_slice0370_norm8.tif
# ------------------------------------------------------------
# roi_0296_slice0371.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0296_slice0371_norm8.tif
# ------------------------------------------------------------
# roi_0297_slice0372.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0297_slice0372_norm8.tif
# ------------------------------------------------------------
# roi_0298_slice0373.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=122
#  -> saved: roi_0298_slice0373_norm8.tif
# ------------------------------------------------------------
# roi_0299_slice0374.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0299_slice0374_norm8.tif
# ------------------------------------------------------------
# roi_0300_slice0375.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0300_slice0375_norm8.tif
# ------------------------------------------------------------
# roi_0301_slice0376.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_0301_slice0376_norm8.tif
# ------------------------------------------------------------
# roi_0302_slice0377.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_0302_slice0377_norm8.tif
# ------------------------------------------------------------
# roi_0303_slice0378.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0303_slice0378_norm8.tif
# ------------------------------------------------------------
# roi_0304_slice0379.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0304_slice0379_norm8.tif
# ------------------------------------------------------------
# roi_0305_slice0380.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0305_slice0380_norm8.tif
# ------------------------------------------------------------
# roi_0306_slice0381.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0306_slice0381_norm8.tif
# ------------------------------------------------------------
# roi_0307_slice0382.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0307_slice0382_norm8.tif
# ------------------------------------------------------------
# roi_0308_slice0383.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=138
#  -> saved: roi_0308_slice0383_norm8.tif
# ------------------------------------------------------------
# roi_0309_slice0384.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0309_slice0384_norm8.tif
# ------------------------------------------------------------
# roi_0310_slice0385.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0310_slice0385_norm8.tif
# ------------------------------------------------------------
# roi_0311_slice0386.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0311_slice0386_norm8.tif
# ------------------------------------------------------------
# roi_0312_slice0387.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0312_slice0387_norm8.tif
# ------------------------------------------------------------
# roi_0313_slice0388.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0313_slice0388_norm8.tif
# ------------------------------------------------------------
# roi_0314_slice0389.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0314_slice0389_norm8.tif
# ------------------------------------------------------------
# roi_0315_slice0390.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0315_slice0390_norm8.tif
# ------------------------------------------------------------
# roi_0316_slice0391.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=121
#  -> saved: roi_0316_slice0391_norm8.tif
# ------------------------------------------------------------
# roi_0317_slice0392.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=122
#  -> saved: roi_0317_slice0392_norm8.tif
# ------------------------------------------------------------
# roi_0318_slice0393.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0318_slice0393_norm8.tif
# ------------------------------------------------------------
# roi_0319_slice0394.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0319_slice0394_norm8.tif
# ------------------------------------------------------------
# roi_0320_slice0395.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0320_slice0395_norm8.tif
# ------------------------------------------------------------
# roi_0321_slice0396.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0321_slice0396_norm8.tif
# ------------------------------------------------------------
# roi_0322_slice0397.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0322_slice0397_norm8.tif
# ------------------------------------------------------------
# roi_0323_slice0398.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0323_slice0398_norm8.tif
# ------------------------------------------------------------
# roi_0324_slice0399.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0324_slice0399_norm8.tif
# ------------------------------------------------------------
# roi_0325_slice0400.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0325_slice0400_norm8.tif
# ------------------------------------------------------------
# roi_0326_slice0401.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0326_slice0401_norm8.tif
# ------------------------------------------------------------
# roi_0327_slice0402.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0327_slice0402_norm8.tif
# ------------------------------------------------------------
# roi_0328_slice0403.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0328_slice0403_norm8.tif
# ------------------------------------------------------------
# roi_0329_slice0404.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0329_slice0404_norm8.tif
# ------------------------------------------------------------
# roi_0330_slice0405.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0330_slice0405_norm8.tif
# ------------------------------------------------------------
# roi_0331_slice0406.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0331_slice0406_norm8.tif
# ------------------------------------------------------------
# roi_0332_slice0407.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0332_slice0407_norm8.tif
# ------------------------------------------------------------
# roi_0333_slice0408.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0333_slice0408_norm8.tif
# ------------------------------------------------------------
# roi_0334_slice0409.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0334_slice0409_norm8.tif
# ------------------------------------------------------------
# roi_0335_slice0410.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0335_slice0410_norm8.tif
# ------------------------------------------------------------
# roi_0336_slice0411.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0336_slice0411_norm8.tif
# ------------------------------------------------------------
# roi_0337_slice0412.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0337_slice0412_norm8.tif
# ------------------------------------------------------------
# roi_0338_slice0413.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0338_slice0413_norm8.tif
# ------------------------------------------------------------
# roi_0339_slice0414.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0339_slice0414_norm8.tif
# ------------------------------------------------------------
# roi_0340_slice0415.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0340_slice0415_norm8.tif
# ------------------------------------------------------------
# roi_0341_slice0416.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0341_slice0416_norm8.tif
# ------------------------------------------------------------
# roi_0342_slice0417.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0342_slice0417_norm8.tif
# ------------------------------------------------------------
# roi_0343_slice0418.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=144
#  -> saved: roi_0343_slice0418_norm8.tif
# ------------------------------------------------------------
# roi_0344_slice0419.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0344_slice0419_norm8.tif
# ------------------------------------------------------------
# roi_0345_slice0420.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0345_slice0420_norm8.tif
# ------------------------------------------------------------
# roi_0346_slice0421.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0346_slice0421_norm8.tif
# ------------------------------------------------------------
# roi_0347_slice0422.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=143
#  -> saved: roi_0347_slice0422_norm8.tif
# ------------------------------------------------------------
# roi_0348_slice0423.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0348_slice0423_norm8.tif
# ------------------------------------------------------------
# roi_0349_slice0424.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0349_slice0424_norm8.tif
# ------------------------------------------------------------
# roi_0350_slice0425.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0350_slice0425_norm8.tif
# ------------------------------------------------------------
# roi_0351_slice0426.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=140
#  -> saved: roi_0351_slice0426_norm8.tif
# ------------------------------------------------------------
# roi_0352_slice0427.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0352_slice0427_norm8.tif
# ------------------------------------------------------------
# roi_0353_slice0428.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0353_slice0428_norm8.tif
# ------------------------------------------------------------
# roi_0354_slice0429.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0354_slice0429_norm8.tif
# ------------------------------------------------------------
# roi_0355_slice0430.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0355_slice0430_norm8.tif
# ------------------------------------------------------------
# roi_0356_slice0431.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0356_slice0431_norm8.tif
# ------------------------------------------------------------
# roi_0357_slice0432.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0357_slice0432_norm8.tif
# ------------------------------------------------------------
# roi_0358_slice0433.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0358_slice0433_norm8.tif
# ------------------------------------------------------------
# roi_0359_slice0434.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0359_slice0434_norm8.tif
# ------------------------------------------------------------
# roi_0360_slice0435.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0360_slice0435_norm8.tif
# ------------------------------------------------------------
# roi_0361_slice0436.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0361_slice0436_norm8.tif
# ------------------------------------------------------------
# roi_0362_slice0437.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0362_slice0437_norm8.tif
# ------------------------------------------------------------
# roi_0363_slice0438.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0363_slice0438_norm8.tif
# ------------------------------------------------------------
# roi_0364_slice0439.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0364_slice0439_norm8.tif
# ------------------------------------------------------------
# roi_0365_slice0440.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_0365_slice0440_norm8.tif
# ------------------------------------------------------------
# roi_0366_slice0441.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_0366_slice0441_norm8.tif
# ------------------------------------------------------------
# roi_0367_slice0442.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0367_slice0442_norm8.tif
# ------------------------------------------------------------
# roi_0368_slice0443.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0368_slice0443_norm8.tif
# ------------------------------------------------------------
# roi_0369_slice0444.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0369_slice0444_norm8.tif
# ------------------------------------------------------------
# roi_0370_slice0445.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0370_slice0445_norm8.tif
# ------------------------------------------------------------
# roi_0371_slice0446.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0371_slice0446_norm8.tif
# ------------------------------------------------------------
# roi_0372_slice0447.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0372_slice0447_norm8.tif
# ------------------------------------------------------------
# roi_0373_slice0448.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0373_slice0448_norm8.tif
# ------------------------------------------------------------
# roi_0374_slice0449.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0374_slice0449_norm8.tif
# ------------------------------------------------------------
# roi_0375_slice0450.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_0375_slice0450_norm8.tif
# ------------------------------------------------------------
# roi_0376_slice0451.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0376_slice0451_norm8.tif
# ------------------------------------------------------------
# roi_0377_slice0452.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0377_slice0452_norm8.tif
# ------------------------------------------------------------
# roi_0378_slice0453.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_0378_slice0453_norm8.tif
# ------------------------------------------------------------
# roi_0379_slice0454.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0379_slice0454_norm8.tif
# ------------------------------------------------------------
# roi_0380_slice0455.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_0380_slice0455_norm8.tif
# ------------------------------------------------------------
# roi_0381_slice0456.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0381_slice0456_norm8.tif
# ------------------------------------------------------------
# roi_0382_slice0457.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0382_slice0457_norm8.tif
# ------------------------------------------------------------
# roi_0383_slice0458.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0383_slice0458_norm8.tif
# ------------------------------------------------------------
# roi_0384_slice0459.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0384_slice0459_norm8.tif
# ------------------------------------------------------------
# roi_0385_slice0460.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=139
#  -> saved: roi_0385_slice0460_norm8.tif
# ------------------------------------------------------------
# roi_0386_slice0461.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=138
#  -> saved: roi_0386_slice0461_norm8.tif
# ------------------------------------------------------------
# roi_0387_slice0462.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=140
#  -> saved: roi_0387_slice0462_norm8.tif
# ------------------------------------------------------------
# roi_0388_slice0463.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=140
#  -> saved: roi_0388_slice0463_norm8.tif
# ------------------------------------------------------------
# roi_0389_slice0464.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0389_slice0464_norm8.tif
# ------------------------------------------------------------
# roi_0390_slice0465.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=142
#  -> saved: roi_0390_slice0465_norm8.tif
# ------------------------------------------------------------
# roi_0391_slice0466.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0391_slice0466_norm8.tif
# ------------------------------------------------------------
# roi_0392_slice0467.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0392_slice0467_norm8.tif
# ------------------------------------------------------------
# roi_0393_slice0468.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0393_slice0468_norm8.tif
# ------------------------------------------------------------
# roi_0394_slice0469.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_0394_slice0469_norm8.tif
# ------------------------------------------------------------
# roi_0395_slice0470.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=140
#  -> saved: roi_0395_slice0470_norm8.tif
# ------------------------------------------------------------
# roi_0396_slice0471.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0396_slice0471_norm8.tif
# ------------------------------------------------------------
# roi_0397_slice0472.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0397_slice0472_norm8.tif
# ------------------------------------------------------------
# roi_0398_slice0473.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0398_slice0473_norm8.tif
# ------------------------------------------------------------
# roi_0399_slice0474.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_0399_slice0474_norm8.tif
# ------------------------------------------------------------
# roi_0400_slice0475.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0400_slice0475_norm8.tif
# ------------------------------------------------------------
# roi_0401_slice0476.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=147
#  -> saved: roi_0401_slice0476_norm8.tif
# ------------------------------------------------------------
# roi_0402_slice0477.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=138
#  -> saved: roi_0402_slice0477_norm8.tif
# ------------------------------------------------------------
# roi_0403_slice0478.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0403_slice0478_norm8.tif
# ------------------------------------------------------------
# roi_0404_slice0479.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_0404_slice0479_norm8.tif
# ------------------------------------------------------------
# roi_0405_slice0480.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0405_slice0480_norm8.tif
# ------------------------------------------------------------
# roi_0406_slice0481.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0406_slice0481_norm8.tif
# ------------------------------------------------------------
# roi_0407_slice0482.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_0407_slice0482_norm8.tif
# ------------------------------------------------------------
# roi_0408_slice0483.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_0408_slice0483_norm8.tif
# ------------------------------------------------------------
# roi_0409_slice0484.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0409_slice0484_norm8.tif
# ------------------------------------------------------------
# roi_0410_slice0485.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0410_slice0485_norm8.tif
# ------------------------------------------------------------
# roi_0411_slice0486.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0411_slice0486_norm8.tif
# ------------------------------------------------------------
# roi_0412_slice0487.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0412_slice0487_norm8.tif
# ------------------------------------------------------------
# roi_0413_slice0488.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_0413_slice0488_norm8.tif
# ------------------------------------------------------------
# roi_0414_slice0489.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=136
#  -> saved: roi_0414_slice0489_norm8.tif
# ------------------------------------------------------------
# roi_0415_slice0490.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0415_slice0490_norm8.tif
# ------------------------------------------------------------
# roi_0416_slice0491.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0416_slice0491_norm8.tif
# ------------------------------------------------------------
# roi_0417_slice0492.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_0417_slice0492_norm8.tif
# ------------------------------------------------------------
# roi_0418_slice0493.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_0418_slice0493_norm8.tif
# ------------------------------------------------------------
# roi_0419_slice0494.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_0419_slice0494_norm8.tif
# ------------------------------------------------------------
# roi_0420_slice0495.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_0420_slice0495_norm8.tif
# ------------------------------------------------------------
# roi_0421_slice0496.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_0421_slice0496_norm8.tif
# ------------------------------------------------------------
# roi_0422_slice0497.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_0422_slice0497_norm8.tif
# ------------------------------------------------------------
# ...
# ------------------------------------------------------------
# roi_1130_slice1205.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1130_slice1205_norm8.tif
# ------------------------------------------------------------
# roi_1131_slice1206.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1131_slice1206_norm8.tif
# ------------------------------------------------------------
# roi_1132_slice1207.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=117
#  -> saved: roi_1132_slice1207_norm8.tif
# ------------------------------------------------------------
# roi_1133_slice1208.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_1133_slice1208_norm8.tif
# ------------------------------------------------------------
# roi_1134_slice1209.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_1134_slice1209_norm8.tif
# ------------------------------------------------------------
# roi_1135_slice1210.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=122
#  -> saved: roi_1135_slice1210_norm8.tif
# ------------------------------------------------------------
# roi_1136_slice1211.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1136_slice1211_norm8.tif
# ------------------------------------------------------------
# roi_1137_slice1212.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_1137_slice1212_norm8.tif
# ------------------------------------------------------------
# roi_1138_slice1213.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=141
#  -> saved: roi_1138_slice1213_norm8.tif
# ------------------------------------------------------------
# roi_1139_slice1214.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_1139_slice1214_norm8.tif
# ------------------------------------------------------------
# roi_1140_slice1215.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=134
#  -> saved: roi_1140_slice1215_norm8.tif
# ------------------------------------------------------------
# roi_1141_slice1216.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_1141_slice1216_norm8.tif
# ------------------------------------------------------------
# roi_1142_slice1217.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1142_slice1217_norm8.tif
# ------------------------------------------------------------
# roi_1143_slice1218.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_1143_slice1218_norm8.tif
# ------------------------------------------------------------
# roi_1144_slice1219.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=118
#  -> saved: roi_1144_slice1219_norm8.tif
# ------------------------------------------------------------
# roi_1145_slice1220.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1145_slice1220_norm8.tif
# ------------------------------------------------------------
# roi_1146_slice1221.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_1146_slice1221_norm8.tif
# ------------------------------------------------------------
# roi_1147_slice1222.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=121
#  -> saved: roi_1147_slice1222_norm8.tif
# ------------------------------------------------------------
# roi_1148_slice1223.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1148_slice1223_norm8.tif
# ------------------------------------------------------------
# roi_1149_slice1224.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1149_slice1224_norm8.tif
# ------------------------------------------------------------
# roi_1150_slice1225.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_1150_slice1225_norm8.tif
# ------------------------------------------------------------
# roi_1151_slice1226.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_1151_slice1226_norm8.tif
# ------------------------------------------------------------
# roi_1152_slice1227.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1152_slice1227_norm8.tif
# ------------------------------------------------------------
# roi_1153_slice1228.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=138
#  -> saved: roi_1153_slice1228_norm8.tif
# ------------------------------------------------------------
# roi_1154_slice1229.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1154_slice1229_norm8.tif
# ------------------------------------------------------------
# roi_1155_slice1230.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_1155_slice1230_norm8.tif
# ------------------------------------------------------------
# roi_1156_slice1231.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1156_slice1231_norm8.tif
# ------------------------------------------------------------
# roi_1157_slice1232.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_1157_slice1232_norm8.tif
# ------------------------------------------------------------
# roi_1158_slice1233.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_1158_slice1233_norm8.tif
# ------------------------------------------------------------
# roi_1159_slice1234.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1159_slice1234_norm8.tif
# ------------------------------------------------------------
# roi_1160_slice1235.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_1160_slice1235_norm8.tif
# ------------------------------------------------------------
# roi_1161_slice1236.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1161_slice1236_norm8.tif
# ------------------------------------------------------------
# roi_1162_slice1237.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_1162_slice1237_norm8.tif
# ------------------------------------------------------------
# roi_1163_slice1238.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_1163_slice1238_norm8.tif
# ------------------------------------------------------------
# roi_1164_slice1239.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1164_slice1239_norm8.tif
# ------------------------------------------------------------
# roi_1165_slice1240.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1165_slice1240_norm8.tif
# ------------------------------------------------------------
# roi_1166_slice1241.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_1166_slice1241_norm8.tif
# ------------------------------------------------------------
# roi_1167_slice1242.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_1167_slice1242_norm8.tif
# ------------------------------------------------------------
# roi_1168_slice1243.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_1168_slice1243_norm8.tif
# ------------------------------------------------------------
# roi_1169_slice1244.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1169_slice1244_norm8.tif
# ------------------------------------------------------------
# roi_1170_slice1245.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1170_slice1245_norm8.tif
# ------------------------------------------------------------
# roi_1171_slice1246.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=138
#  -> saved: roi_1171_slice1246_norm8.tif
# ------------------------------------------------------------
# roi_1172_slice1247.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_1172_slice1247_norm8.tif
# ------------------------------------------------------------
# roi_1173_slice1248.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=135
#  -> saved: roi_1173_slice1248_norm8.tif
# ------------------------------------------------------------
# roi_1174_slice1249.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=144
#  -> saved: roi_1174_slice1249_norm8.tif
# ------------------------------------------------------------
# roi_1175_slice1250.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_1175_slice1250_norm8.tif
# ------------------------------------------------------------
# roi_1176_slice1251.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1176_slice1251_norm8.tif
# ------------------------------------------------------------
# roi_1177_slice1252.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_1177_slice1252_norm8.tif
# ------------------------------------------------------------
# roi_1178_slice1253.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1178_slice1253_norm8.tif
# ------------------------------------------------------------
# roi_1179_slice1254.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=137
#  -> saved: roi_1179_slice1254_norm8.tif
# ------------------------------------------------------------
# roi_1180_slice1255.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=131
#  -> saved: roi_1180_slice1255_norm8.tif
# ------------------------------------------------------------
# roi_1181_slice1256.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1181_slice1256_norm8.tif
# ------------------------------------------------------------
# roi_1182_slice1257.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=120
#  -> saved: roi_1182_slice1257_norm8.tif
# ------------------------------------------------------------
# roi_1183_slice1258.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=128
#  -> saved: roi_1183_slice1258_norm8.tif
# ------------------------------------------------------------
# roi_1184_slice1259.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1184_slice1259_norm8.tif
# ------------------------------------------------------------
# roi_1185_slice1260.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=133
#  -> saved: roi_1185_slice1260_norm8.tif
# ------------------------------------------------------------
# roi_1186_slice1261.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=129
#  -> saved: roi_1186_slice1261_norm8.tif
# ------------------------------------------------------------
# roi_1187_slice1262.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=125
#  -> saved: roi_1187_slice1262_norm8.tif
# ------------------------------------------------------------
# roi_1188_slice1263.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=127
#  -> saved: roi_1188_slice1263_norm8.tif
# ------------------------------------------------------------
# roi_1189_slice1264.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_1189_slice1264_norm8.tif
# ------------------------------------------------------------
# roi_1190_slice1265.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1190_slice1265_norm8.tif
# ------------------------------------------------------------
# roi_1191_slice1266.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_1191_slice1266_norm8.tif
# ------------------------------------------------------------
# roi_1192_slice1267.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1192_slice1267_norm8.tif
# ------------------------------------------------------------
# roi_1193_slice1268.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=121
#  -> saved: roi_1193_slice1268_norm8.tif
# ------------------------------------------------------------
# roi_1194_slice1269.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=122
#  -> saved: roi_1194_slice1269_norm8.tif
# ------------------------------------------------------------
# roi_1195_slice1270.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=122
#  -> saved: roi_1195_slice1270_norm8.tif
# ------------------------------------------------------------
# roi_1196_slice1271.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_1196_slice1271_norm8.tif
# ------------------------------------------------------------
# roi_1197_slice1272.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=132
#  -> saved: roi_1197_slice1272_norm8.tif
# ------------------------------------------------------------
# roi_1198_slice1273.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_1198_slice1273_norm8.tif
# ------------------------------------------------------------
# roi_1199_slice1274.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=124
#  -> saved: roi_1199_slice1274_norm8.tif
# ------------------------------------------------------------
# roi_1200_slice1275.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=123
#  -> saved: roi_1200_slice1275_norm8.tif
# ------------------------------------------------------------
# roi_1201_slice1276.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=130
#  -> saved: roi_1201_slice1276_norm8.tif
# ------------------------------------------------------------
# roi_1202_slice1277.tif: dtype=uint16, shape=(650, 650)
#  -> uint8: dtype=uint8, min=0, max=255
#  -> mode(100..254)=126
#  -> saved: roi_1202_slice1277_norm8.tif
# ------------------------------------------------------------
# Done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
