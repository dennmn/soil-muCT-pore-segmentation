# %%
# %cd /content/drive/MyDrive/soil_microCT_images/drive_scripts/pores_analysis/
# Out:
# /content/drive/MyDrive/soil_microCT_images/drive_scripts/pores_analysis

# %%
# !python run_tests.py
# Out:
# ...
# PSD VALIDATION TEST RUNNER
# ...
#
# Module path: /content/drive/MyDrive/soil_microCT_images/drive_scripts/pores_analysis
# Importing test suite...
#
# ...
# PSD SYNTHETIC VALIDATION TEST SUITE
# ...
#
# These tests validate the EDT → Opening → PSD pipeline
# using synthetic volumes with known analytical solutions.
#
# Note: Small deviations are expected due to discretization.
#
# ...
# TEST 1: Single Sphere
# ...
# Volume: (128, 128, 128), porosity: 0.0159
# Expected diameter: 40 voxels
# ...
# PSD Calculator - Pipeline Execution
# ...
# Volume shape: (128, 128, 128)
# Voxel spacing: (1.0, 1.0, 1.0) μm
# Porosity: 0.0159
# GPU: True, Chunking: False
#
# [1/3] Computing Euclidean Distance Transform...
#   EDT complete. Max distance: 20.02 μm
#
# [2/3] Computing Opening Map (Morphological Reconstruction)...
#   Computing Opening Map (GPU Iterative, Max Radius: 20)...
#   Opening complete. Max radius: 40.00 μm
#
# [3/3] Extracting Pore Size Distribution...
#
# ...
# PSD Calculation Complete
# ...
# Total pore voxels analyzed: 33,401
# ...
